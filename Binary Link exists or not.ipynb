# %%
import pandas as pd

# %%
df = pd.read_pickle("df_cleaned.pkl")

# %%
df
# Out:
#          Article                                              Title  \
# 1      Article 1                                              Scope
# 2      Article 2                                 Supervisory powers
# 3      Article 3  Application of stricter requirements by instit...
# 4      Article 4                                        Definitions
# 5      Article 5  Definitions specific to capital requirements f...
# 6      Article 6                                 General principles
# 7      Article 7  Derogation to the application of prudential re...
# 8      Article 8  Derogation to the application of liquidity req...
# 9      Article 9                    Individual consolidation method
# 10    Article 10  Waiver for credit institutions permanently aff...
# 11    Article 11                                  General treatment
# 12    Article 12  Financial holding company or mixed financial h...
# 13    Article 13  Application of disclosure requirements on a co...
# ...

# %%
def link(x):
    if not x:
        y = 0
    else:
        y = 1
    return y

# %%
df['Link'] = df['References_internal_clean'].apply(link)

# %%
df
# Out:
#          Article                                              Title  \
# 1      Article 1                                              Scope
# 2      Article 2                                 Supervisory powers
# 3      Article 3  Application of stricter requirements by instit...
# 4      Article 4                                        Definitions
# 5      Article 5  Definitions specific to capital requirements f...
# 6      Article 6                                 General principles
# 7      Article 7  Derogation to the application of prudential re...
# 8      Article 8  Derogation to the application of liquidity req...
# 9      Article 9                    Individual consolidation method
# 10    Article 10  Waiver for credit institutions permanently aff...
# 11    Article 11                                  General treatment
# 12    Article 12  Financial holding company or mixed financial h...
# 13    Article 13  Application of disclosure requirements on a co...
# ...

# %%
df.to_pickle("df_cleaned_links.pkl")
