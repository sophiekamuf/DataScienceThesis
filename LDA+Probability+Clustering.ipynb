# %%
import scipy
import numpy as np
import gensim
import re
import pandas as pd
from sklearn import feature_extraction
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sophiekamuf/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_pickle("df_cleaned.pkl")

# %%
df.head()
# Out:
#      Article                                              Title  \
# 1  Article 1                                              Scope
# 2  Article 2                                 Supervisory powers
# 3  Article 3  Application of stricter requirements by instit...
# 4  Article 4                                        Definitions
# 5  Article 5  Definitions specific to capital requirements f...
#
#                                           Paragraphs  \
# 1  This Regulation lays down uniform rules concer...
# 2  For the purposes of ensuring compliance with t...
# 3  This Regulation shall not prevent institutions...
# 4  1.   For the purposes of this Regulation, the ...
# 5  For the purposes of Part Three, Title II, the ...
#
#           References_internal_clean  \
# 1                             [460]
# 2                                []
# 3                                []
# 4  [4, 2, 115, 25, 71, 301, 113, 1]
# 5                                []
#
#                                   Paragraphs_cleaned
# 1  This Regulation lays down uniform rules concer...
# 2  For the purposes of ensuring compliance with t...
# 3  This Regulation shall not prevent institutions...
# 4  1.   For the purposes of this Regulation, the ...
# 5  For the purposes of Part Three, Title II, the ...

# %%
paragraphs = df['Paragraphs_cleaned'].tolist()

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
p_stemmer = PorterStemmer()

# %%
texts = []

# %%
for i in paragraphs:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in stopwords]
    
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)

# %%
texts
# Out:
# [['regul',
#   'lay',
#   'uniform',
#   'rule',
#   'concern',
#   'gener',
#   'prudenti',
#   'requir',
#   'institut',
#   'supervis',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'shall',
#   'compli',
#   'relat',
#   'follow',
#   'item',
#   'fund',
#   'requir',
#   'relat',
#   'entir',
#   'quantifi',
#   'uniform',
#   'standardis',
#   'element',
#   'credit',
#   'risk',
#   'market',
#   'risk',
#   'oper',
#   'risk',
#   'settlement',
#   'risk',
#   'b',
#   'requir',
#   'limit',
#   'larg',
#   'exposur',
#   'c',
#   'deleg',
#   'act',
#   'refer',
#   'enter',
#   'forc',
#   'liquid',
#   'requir',
#   'relat',
#   'entir',
#   'quantifi',
#   'uniform',
#   'standardis',
#   'element',
#   'liquid',
#   'risk',
#   'report',
#   'requir',
#   'relat',
#   'point',
#   'b',
#   'c',
#   'leverag',
#   'e',
#   'public',
#   'disclosur',
#   'requir',
#   'regul',
#   'govern',
#   'public',
#   'requir',
#   'compet',
#   'author',
#   'field',
#   'prudenti',
#   'regul',
#   'supervis',
#   'institut',
#   'set',
#   'direct',
#   '2013',
#   '36',
#   'eu'],
#  ['purpos',
#   'ensur',
#   'complianc',
#   'regul',
#   'compet',
#   'author',
#   'shall',
#   'power',
#   'shall',
#   'follow',
#   'procedur',
#   'set',
#   'direct',
#   '2013',
#   '36',
#   'eu'],
#  ['regul',
#   'shall',
#   'prevent',
#   'institut',
#   'hold',
#   'fund',
#   'compon',
#   'excess',
#   'appli',
#   'measur',
#   'stricter',
#   'requir',
#   'regul'],
#  ['1',
#   'purpos',
#   'regul',
#   'follow',
#   'definit',
#   'shall',
#   'appli',
#   '1',
#   'credit',
#   'institut',
#   'mean',
#   'undertak',
#   'busi',
#   'take',
#   'deposit',
#   'repay',
#   'fund',
#   'public',
#   'grant',
#   'credit',
#   'account',
#   '2',
#   'invest',
#   'firm',
#   'mean',
#   'person',
#   'defin',
#   'point',
#   '1',
#   'articl',
#   '4',
#   '1',
#   'direct',
#   '2004',
#   '39',
#   'ec',
#   'subject',
#   'requir',
#   'impos',
#   'direct',
#   'exclud',
#   'follow',
#   'credit',
#   'institut',
#   'b',
#   'local',
#   'firm',
#   'c',
#   'firm',
#   'authoris',
#   'provid',
#   'ancillari',
#   'servic',
#   'refer',
#   'point',
#   '1',
#   'section',
#   'b',
#   'annex',
#   'direct',
#   '2004',
#   '39',
#   'ec',
#   'provid',
#   'one',
#   'invest',
#   'servic',
#   'activ',
#   'list',
#   'point',
#   '1',
#   '2',
#   '4',
#   '5',
#   'section',
#   'annex',
#   'direct',
#   'permit',
#   'hold',
#   'money',
#   'secur',
#   'belong',
#   'client',
#   'reason',
#   'may',
#   'time',
#   'place',
#   'debt',
#   'client',
#   '3',
#   'institut',
#   'mean',
#   'credit',
#   'institut',
#   'invest',
#   'firm',
#   '4',
#   'local',
#   'firm',
#   'mean',
#   'firm',
#   'deal',
#   'account',
#   'market',
#   'financi',
#   'futur',
#   'option',
#   'deriv',
#   'cash',
#   'market',
#   'sole',
#   'purpos',
#   'hedg',
#   'posit',
#   'deriv',
#   'market',
#   'deal',
#   'account',
#   'member',
#   'market',
#   'guarante',
#   'clear',
#   'member',
#   'market',
#   'respons',
#   'ensur',
#   'perform',
#   'contract',
#   'enter',
#   'firm',
#   'assum',
#   'clear',
#   'member',
#   'market',
#   '5',
#   'insur',
#   'undertak',
#   'mean',
#   'insur',
#   'undertak',
#   'defin',
#   'point',
#   '1',
#   'articl',
#   '13',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   'european',
#   'parliament',
#   'council',
#   '25',
#   'novemb',
#   '2009',
#   'take',
#   'pursuit',
#   'busi',
#   'insur',
#   'reinsur',
#   'solvenc',
#   'ii',
#   '20',
#   '6',
#   'reinsur',
#   'undertak',
#   'mean',
#   'reinsur',
#   'undertak',
#   'defin',
#   'point',
#   '4',
#   'articl',
#   '13',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   '7',
#   'collect',
#   'invest',
#   'undertak',
#   'ciu',
#   'mean',
#   'ucit',
#   'defin',
#   'articl',
#   '1',
#   '2',
#   'direct',
#   '2009',
#   '65',
#   'ec',
#   'european',
#   'parliament',
#   'council',
#   '13',
#   'juli',
#   '2009',
#   'coordin',
#   'law',
#   'regul',
#   'administr',
#   'provis',
#   'relat',
#   'undertak',
#   'collect',
#   'invest',
#   'transfer',
#   'secur',
#   'ucit',
#   '21',
#   'includ',
#   'unless',
#   'otherwis',
#   'provid',
#   'third',
#   'countri',
#   'entiti',
#   'carri',
#   'similar',
#   'activ',
#   'subject',
#   'supervis',
#   'pursuant',
#   'union',
#   'law',
#   'law',
#   'third',
#   'countri',
#   'appli',
#   'supervisori',
#   'regulatori',
#   'requir',
#   'least',
#   'equival',
#   'appli',
#   'union',
#   'aif',
#   'defin',
#   'direct',
#   '2011',
#   '61',
#   'eu',
#   'european',
#   'parliament',
#   'council',
#   '8',
#   'june',
#   '2011',
#   'altern',
#   'invest',
#   'fund',
#   'manag',
#   '22',
#   'non',
#   'eu',
#   'aif',
#   'defin',
#   'aa',
#   'direct',
#   '8',
#   'public',
#   'sector',
#   'entiti',
#   'mean',
#   'non',
#   'commerci',
#   'administr',
#   'bodi',
#   'respons',
#   'central',
#   'govern',
#   'region',
#   'govern',
#   'local',
#   'author',
#   'author',
#   'exercis',
#   'respons',
#   'region',
#   'govern',
#   'local',
#   'author',
#   'non',
#   'commerci',
#   'undertak',
#   'own',
#   'set',
#   'sponsor',
#   'central',
#   'govern',
#   'region',
#   'govern',
#   'local',
#   'author',
#   'explicit',
#   'guarante',
#   'arrang',
#   'may',
#   'includ',
#   'self',
#   'administ',
#   'bodi',
#   'govern',
#   'law',
#   'public',
#   'supervis',
#   '9',
#   'manag',
#   'bodi',
#   'mean',
#   'manag',
#   'bodi',
#   'defin',
#   'point',
#   '7',
#   'articl',
#   '3',
#   '1',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '10',
#   'senior',
#   'manag',
#   'mean',
#   'senior',
#   'manag',
#   'defin',
#   'point',
#   '9',
#   'articl',
#   '3',
#   '1',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '11',
#   'system',
#   'risk',
#   'mean',
#   'system',
#   'risk',
#   'defin',
#   'point',
#   '10',
#   'articl',
#   '3',
#   '1',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '12',
#   'model',
#   'risk',
#   'mean',
#   'model',
#   'risk',
#   'defin',
#   'point',
#   '11',
#   'articl',
#   '3',
#   '1',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '13',
#   'origin',
#   'mean',
#   'entiti',
#   'relat',
#   'entiti',
#   'directli',
#   'indirectli',
#   'involv',
#   'origin',
#   'agreement',
#   'creat',
#   'oblig',
#   'potenti',
#   'oblig',
#   'debtor',
#   'potenti',
#   'debtor',
#   'give',
#   'rise',
#   'exposur',
#   'securitis',
#   'b',
#   'purchas',
#   'third',
#   'parti',
#   'exposur',
#   'account',
#   'securitis',
#   '14',
#   'sponsor',
#   'mean',
#   'institut',
#   'origin',
#   'institut',
#   'establish',
#   'manag',
#   'asset',
#   'back',
#   'commerci',
#   'paper',
#   'programm',
#   'securitis',
#   'scheme',
#   'purchas',
#   'exposur',
#   'third',
#   'parti',
#   'entiti',
#   '15',
#   'parent',
#   'undertak',
#   'mean',
#   'parent',
#   'undertak',
#   'within',
#   'mean',
#   'articl',
#   '1',
#   '2',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'b',
#   'purpos',
#   'section',
#   'ii',
#   'chapter',
#   '3',
#   '4',
#   'titl',
#   'vii',
#   'titl',
#   'viii',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'part',
#   'five',
#   'regul',
#   'parent',
#   'undertak',
#   'within',
#   'mean',
#   'articl',
#   '1',
#   '1',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'undertak',
#   'effect',
#   'exercis',
#   'domin',
#   'influenc',
#   'anoth',
#   'undertak',
#   '16',
#   'subsidiari',
#   'mean',
#   'subsidiari',
#   'undertak',
#   'within',
#   'mean',
#   'articl',
#   '1',
#   '2',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'b',
#   'subsidiari',
#   'undertak',
#   'within',
#   'mean',
#   'articl',
#   '1',
#   '1',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'undertak',
#   'parent',
#   'undertak',
#   'effect',
#   'exercis',
#   'domin',
#   'influenc',
#   'subsidiari',
#   'subsidiari',
#   'shall',
#   'also',
#   'consid',
#   'subsidiari',
#   'undertak',
#   'origin',
#   'parent',
#   'undertak',
#   '17',
#   'branch',
#   'mean',
#   'place',
#   'busi',
#   'form',
#   'legal',
#   'depend',
#   'part',
#   'institut',
#   'carri',
#   'directli',
#   'transact',
#   'inher',
#   'busi',
#   'institut',
#   '18',
#   'ancillari',
#   'servic',
#   'undertak',
#   'mean',
#   'undertak',
#   'princip',
#   'activ',
#   'consist',
#   'own',
#   'manag',
#   'properti',
#   'manag',
#   'data',
#   'process',
#   'servic',
#   'similar',
#   'activ',
#   'ancillari',
#   'princip',
#   'activ',
#   'one',
#   'institut',
#   '19',
#   'asset',
#   'manag',
#   'compani',
#   'mean',
#   'asset',
#   'manag',
#   'compani',
#   'defin',
#   'point',
#   '5',
#   'articl',
#   '2',
#   'direct',
#   '2002',
#   '87',
#   'ec',
#   'aifm',
#   'defin',
#   'b',
#   'direct',
#   '2011',
#   '61',
#   'eu',
#   'includ',
#   'unless',
#   'otherwis',
#   'provid',
#   'third',
#   'countri',
#   'entiti',
#   'carri',
#   'similar',
#   'activ',
#   'subject',
#   'law',
#   'third',
#   'countri',
#   'appli',
#   'supervisori',
#   'regulatori',
#   'requir',
#   'least',
#   'equival',
#   'appli',
#   'union',
#   '20',
#   'financi',
#   'hold',
#   'compani',
#   'mean',
#   'financi',
#   'institut',
#   'subsidiari',
#   'exclus',
#   'mainli',
#   'institut',
#   'financi',
#   'institut',
#   'least',
#   'one',
#   'subsidiari',
#   'institut',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   '21',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'mean',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'defin',
#   'point',
#   '15',
#   'articl',
#   '2',
#   'direct',
#   '2002',
#   '87',
#   'ec',
#   '22',
#   'mix',
#   'activ',
#   'hold',
#   'compani',
#   'mean',
#   'parent',
#   'undertak',
#   'financi',
#   'hold',
#   'compani',
#   'institut',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'subsidiari',
#   'includ',
#   'least',
#   'one',
#   'institut',
#   '23',
#   'third',
#   'countri',
#   'insur',
#   'undertak',
#   'mean',
#   'third',
#   'countri',
#   'insur',
#   'undertak',
#   'defin',
#   'point',
#   '3',
#   'articl',
#   '13',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   '24',
#   'third',
#   'countri',
#   'reinsur',
#   'undertak',
#   'mean',
#   'third',
#   'countri',
#   'reinsur',
#   'undertak',
#   'defin',
#   'point',
#   '6',
#   'articl',
#   '13',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   '25',
#   'recognis',
#   'third',
#   'countri',
#   'invest',
#   'firm',
#   'mean',
#   'firm',
#   'meet',
#   'follow',
#   'condit',
#   'establish',
#   'within',
#   'union',
#   'would',
#   'cover',
#   'definit',
#   'invest',
#   'firm',
#   'b',
#   'authoris',
#   'third',
#   'countri',
#   'c',
#   'subject',
#   'compli',
#   'prudenti',
#   'rule',
#   'consid',
#   'compet',
#   'author',
#   'least',
#   'stringent',
#   'laid',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '26',
#   'financi',
#   'institut',
#   'mean',
#   'undertak',
#   'institut',
#   'princip',
#   'activ',
#   'acquir',
#   'hold',
#   'pursu',
#   'one',
#   'activ',
#   'list',
#   'point',
#   '2',
#   '12',
#   'point',
#   '15',
#   'annex',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'includ',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'payment',
#   'institut',
#   'within',
#   'mean',
#   'direct',
#   '2007',
#   '64',
#   'ec',
#   'european',
#   'parliament',
#   'council',
#   '13',
#   'novemb',
#   '2007',
#   'payment',
#   'servic',
#   'intern',
#   'market',
#   '23',
#   'asset',
#   'manag',
#   'compani',
#   'exclud',
#   'insur',
#   'hold',
#   'compani',
#   'mix',
#   'activ',
#   'insur',
#   'hold',
#   'compani',
#   'defin',
#   'point',
#   'g',
#   'articl',
#   '212',
#   '1',
#   'direct',
#   '2009',
#   '138',
#   'e',
#   '27',
#   'financi',
#   'sector',
#   'entiti',
#   'mean',
#   'follow',
#   'institut',
#   'b',
#   'financi',
#   'institut',
#   'c',
#   'ancillari',
#   'servic',
#   'undertak',
#   'includ',
#   'consolid',
#   'financi',
#   'situat',
#   'institut',
#   'insur',
#   'undertak',
#   'e',
#   'third',
#   'countri',
#   'insur',
#   'undertak',
#   'f',
#   'reinsur',
#   'undertak',
#   'g',
#   'third',
#   'countri',
#   'reinsur',
#   'undertak',
#   'h',
#   'insur',
#   'hold',
#   'compani',
#   'mix',
#   'activ',
#   'hold',
#   'compani',
#   'j',
#   'mix',
#   'activ',
#   'insur',
#   'hold',
#   'compani',
#   'defin',
#   'point',
#   'g',
#   'articl',
#   '212',
#   '1',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   'k',
#   'undertak',
#   'exclud',
#   'scope',
#   'direct',
#   '2009',
#   '138',
#   'ec',
#   'accord',
#   'articl',
#   '4',
#   'direct',
#   'l',
#   'third',
#   'countri',
#   'undertak',
#   'main',
#   'busi',
#   'compar',
#   'entiti',
#   'refer',
#   'point',
#   'k',
#   '28',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'mean',
#   'institut',
#   'member',
#   'state',
#   'institut',
#   'financi',
#   'institut',
#   'subsidiari',
#   'hold',
#   'particip',
#   'institut',
#   'financi',
#   'institut',
#   'subsidiari',
#   'anoth',
#   'institut',
#   'authoris',
#   'member',
#   'state',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'set',
#   'member',
#   'state',
#   '29',
#   'eu',
#   'parent',
#   'institut',
#   'mean',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'subsidiari',
#   'anoth',
#   'institut',
#   'authoris',
#   'member',
#   'state',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'set',
#   'member',
#   'state',
#   '30',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'mean',
#   'financi',
#   'hold',
#   'compani',
#   'subsidiari',
#   'institut',
#   'authoris',
#   'member',
#   'state',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'set',
#   'member',
#   'state',
#   '31',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'mean',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'subsidiari',
#   'institut',
#   'authoris',
#   'member',
#   'state',
#   'anoth',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   ...],
#  ['purpos',
#   'part',
#   'three',
#   'titl',
#   'ii',
#   'follow',
#   'definit',
#   'shall',
#   'appli',
#   '1',
#   'exposur',
#   'mean',
#   'asset',
#   'balanc',
#   'sheet',
#   'item',
#   '2',
#   'loss',
#   'mean',
#   'econom',
#   'loss',
#   'includ',
#   'materi',
#   'discount',
#   'effect',
#   'materi',
#   'direct',
#   'indirect',
#   'cost',
#   'associ',
#   'collect',
#   'instrument',
#   '3',
#   'expect',
#   'loss',
#   'el',
#   'mean',
#   'ratio',
#   'amount',
#   'expect',
#   'lost',
#   'exposur',
#   'potenti',
#   'default',
#   'counterparti',
#   'dilut',
#   'one',
#   'year',
#   'period',
#   'amount',
#   'outstand',
#   'default'],
#  ['1',
#   'institut',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'two',
#   'five',
#   'eight',
#   'individu',
#   'basi',
#   '2',
#   'everi',
#   'institut',
#   'either',
#   'subsidiari',
#   'member',
#   'state',
#   'authoris',
#   'supervis',
#   'parent',
#   'undertak',
#   'everi',
#   'institut',
#   'includ',
#   'consolid',
#   'pursuant',
#   'requir',
#   'compli',
#   'oblig',
#   'laid',
#   'individu',
#   'basi',
#   '3',
#   'everi',
#   'institut',
#   'either',
#   'parent',
#   'undertak',
#   'subsidiari',
#   'everi',
#   'institut',
#   'includ',
#   'consolid',
#   'pursuant',
#   'requir',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'eight',
#   'individu',
#   'basi',
#   '4',
#   'credit',
#   'institut',
#   'invest',
#   'firm',
#   'authoris',
#   'provid',
#   'invest',
#   'servic',
#   'activ',
#   'list',
#   'point',
#   '3',
#   '6',
#   'section',
#   'annex',
#   'direct',
#   '2004',
#   '39',
#   'ec',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'six',
#   'individu',
#   'basi',
#   'pend',
#   'report',
#   'commiss',
#   'accord',
#   'author',
#   'may',
#   'exempt',
#   'invest',
#   'firm',
#   'complianc',
#   'oblig',
#   'laid',
#   'part',
#   'six',
#   'take',
#   'account',
#   'natur',
#   'scale',
#   'complex',
#   'invest',
#   'firm',
#   'activ',
#   '5',
#   'institut',
#   'except',
#   'invest',
#   'firm',
#   'refer',
#   '96',
#   '1',
#   'institut',
#   'compet',
#   'author',
#   'exercis',
#   'derog',
#   'specifi',
#   '3',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'seven',
#   'individu',
#   'basi'],
#  ['1',
#   'compet',
#   'author',
#   'may',
#   'waiv',
#   'applic',
#   'subsidiari',
#   'institut',
#   'subsidiari',
#   'institut',
#   'subject',
#   'authoris',
#   'supervis',
#   'member',
#   'state',
#   'concern',
#   'subsidiari',
#   'includ',
#   'supervis',
#   'consolid',
#   'basi',
#   'institut',
#   'parent',
#   'undertak',
#   'follow',
#   'condit',
#   'satisfi',
#   'order',
#   'ensur',
#   'fund',
#   'distribut',
#   'adequ',
#   'parent',
#   'undertak',
#   'subsidiari',
#   'current',
#   'foreseen',
#   'materi',
#   'practic',
#   'legal',
#   'impedi',
#   'prompt',
#   'transfer',
#   'fund',
#   'repay',
#   'liabil',
#   'parent',
#   'undertak',
#   'b',
#   'either',
#   'parent',
#   'undertak',
#   'satisfi',
#   'compet',
#   'author',
#   'regard',
#   'prudent',
#   'manag',
#   'subsidiari',
#   'declar',
#   'permiss',
#   'compet',
#   'author',
#   'guarante',
#   'commit',
#   'enter',
#   'subsidiari',
#   'risk',
#   'subsidiari',
#   'neglig',
#   'interest',
#   'c',
#   'risk',
#   'evalu',
#   'measur',
#   'control',
#   'procedur',
#   'parent',
#   'undertak',
#   'cover',
#   'subsidiari',
#   'parent',
#   'undertak',
#   'hold',
#   '50',
#   'vote',
#   'right',
#   'attach',
#   'share',
#   'capit',
#   'subsidiari',
#   'right',
#   'appoint',
#   'remov',
#   'major',
#   'member',
#   'manag',
#   'bodi',
#   'subsidiari',
#   '2',
#   'compet',
#   'author',
#   'may',
#   'exercis',
#   'option',
#   'provid',
#   'paragraph',
#   '1',
#   'parent',
#   'undertak',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'set',
#   'member',
#   'state',
#   'institut',
#   'provid',
#   'subject',
#   'supervis',
#   'exercis',
#   'institut',
#   'particular',
#   'standard',
#   'laid',
#   '3',
#   'compet',
#   'author',
#   'may',
#   'waiv',
#   'applic',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'institut',
#   'subject',
#   'authoris',
#   'supervis',
#   'member',
#   'state',
#   'concern',
#   'includ',
#   'supervis',
#   'consolid',
#   'basi',
#   'follow',
#   'condit',
#   'satisfi',
#   'order',
#   'ensur',
#   'fund',
#   'distribut',
#   'adequ',
#   'among',
#   'parent',
#   'undertak',
#   'subsidiari',
#   'current',
#   'foreseen',
#   'materi',
#   'practic',
#   'legal',
#   'impedi',
#   'prompt',
#   'transfer',
#   'fund',
#   'repay',
#   'liabil',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'b',
#   'risk',
#   'evalu',
#   'measur',
#   'control',
#   'procedur',
#   'relev',
#   'consolid',
#   'supervis',
#   'cover',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'compet',
#   'author',
#   'make',
#   'use',
#   'paragraph',
#   'shall',
#   'inform',
#   'compet',
#   'author',
#   'member',
#   'state'],
#  ['1',
#   'compet',
#   'author',
#   'may',
#   'waiv',
#   'full',
#   'part',
#   'applic',
#   'part',
#   'six',
#   'institut',
#   'subsidiari',
#   'union',
#   'supervis',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'long',
#   'fulfil',
#   'follow',
#   'condit',
#   'parent',
#   'institut',
#   'consolid',
#   'basi',
#   'subsidiari',
#   'institut',
#   'sub',
#   'consolid',
#   'basi',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'six',
#   'b',
#   'parent',
#   'institut',
#   'consolid',
#   'basi',
#   'subsidiari',
#   'institut',
#   'sub',
#   'consolid',
#   'basi',
#   'monitor',
#   'oversight',
#   'time',
#   'liquid',
#   'posit',
#   'institut',
#   'within',
#   'group',
#   'sub',
#   'group',
#   'subject',
#   'waiver',
#   'ensur',
#   'suffici',
#   'level',
#   'liquid',
#   'institut',
#   'c',
#   'institut',
#   'enter',
#   'contract',
#   'satisfact',
#   'compet',
#   'author',
#   'provid',
#   'free',
#   'movement',
#   'fund',
#   'enabl',
#   'meet',
#   'individu',
#   'joint',
#   'oblig',
#   'come',
#   'due',
#   'current',
#   'foreseen',
#   'materi',
#   'practic',
#   'legal',
#   'impedi',
#   'fulfil',
#   'contract',
#   'refer',
#   'c',
#   '1',
#   'januari',
#   '2014',
#   'commiss',
#   'shall',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'legal',
#   'obstacl',
#   'capabl',
#   'render',
#   'imposs',
#   'applic',
#   'point',
#   'c',
#   'first',
#   'subparagraph',
#   'invit',
#   'make',
#   'legisl',
#   'propos',
#   'appropri',
#   '31',
#   'decemb',
#   '2015',
#   'obstacl',
#   'remov',
#   '2',
#   'compet',
#   'author',
#   'may',
#   'waiv',
#   'full',
#   'part',
#   'applic',
#   'part',
#   'six',
#   'institut',
#   'subsidiari',
#   'institut',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'authoris',
#   'member',
#   'state',
#   'provid',
#   'condit',
#   'paragraph',
#   '1',
#   'fulfil',
#   '3',
#   'institut',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'authoris',
#   'sever',
#   'member',
#   'state',
#   'paragraph',
#   '1',
#   'shall',
#   'appli',
#   'follow',
#   'procedur',
#   'laid',
#   'institut',
#   'whose',
#   'compet',
#   'author',
#   'agre',
#   'follow',
#   'element',
#   'assess',
#   'complianc',
#   'organis',
#   'treatment',
#   'liquid',
#   'risk',
#   'condit',
#   'set',
#   'articl',
#   '86',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'across',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'b',
#   'distribut',
#   'amount',
#   'locat',
#   'ownership',
#   'requir',
#   'liquid',
#   'asset',
#   'held',
#   'within',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'c',
#   'determin',
#   'minimum',
#   'amount',
#   'liquid',
#   'asset',
#   'held',
#   'institut',
#   'applic',
#   'part',
#   'six',
#   'waiv',
#   'need',
#   'stricter',
#   'paramet',
#   'set',
#   'part',
#   'six',
#   'e',
#   'unrestrict',
#   'share',
#   'complet',
#   'inform',
#   'compet',
#   'author',
#   'f',
#   'full',
#   'understand',
#   'implic',
#   'waiver',
#   '4',
#   'compet',
#   'author',
#   'may',
#   'also',
#   'appli',
#   'paragraph',
#   '1',
#   '2',
#   '3',
#   'institut',
#   'member',
#   'institut',
#   'protect',
#   'scheme',
#   'refer',
#   'b',
#   'provid',
#   'meet',
#   'condit',
#   'laid',
#   'institut',
#   'link',
#   'relationship',
#   'refer',
#   'provid',
#   'meet',
#   'condit',
#   'laid',
#   'therein',
#   'compet',
#   'author',
#   'shall',
#   'case',
#   'determin',
#   'one',
#   'institut',
#   'subject',
#   'waiver',
#   'meet',
#   'part',
#   'six',
#   'basi',
#   'consolid',
#   'situat',
#   'institut',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   '5',
#   'waiver',
#   'grant',
#   'paragraph',
#   '1',
#   'paragraph',
#   '2',
#   'compet',
#   'author',
#   'may',
#   'also',
#   'appli',
#   'articl',
#   '86',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'part',
#   'thereof',
#   'level',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'waiv',
#   'applic',
#   'articl',
#   '86',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'part',
#   'thereof',
#   'individu',
#   'basi'],
#  ['1',
#   'subject',
#   'paragraph',
#   '2',
#   '3',
#   'articl',
#   '144',
#   '3',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'compet',
#   'author',
#   'may',
#   'permit',
#   'case',
#   'case',
#   'basi',
#   'parent',
#   'institut',
#   'incorpor',
#   'calcul',
#   'requir',
#   'subsidiari',
#   'meet',
#   'condit',
#   'laid',
#   'point',
#   'c',
#   'whose',
#   'materi',
#   'exposur',
#   'materi',
#   'liabil',
#   'parent',
#   'institut',
#   '2',
#   'treatment',
#   'set',
#   'paragraph',
#   '1',
#   'shall',
#   'permit',
#   'parent',
#   'institut',
#   'demonstr',
#   'fulli',
#   'compet',
#   'author',
#   'circumst',
#   'arrang',
#   'includ',
#   'legal',
#   'arrang',
#   'virtu',
#   'materi',
#   'practic',
#   'legal',
#   'impedi',
#   'none',
#   'foreseen',
#   'prompt',
#   'transfer',
#   'fund',
#   'repay',
#   'liabil',
#   'due',
#   'subsidiari',
#   'parent',
#   'undertak',
#   '3',
#   'compet',
#   'author',
#   'exercis',
#   'discret',
#   'laid',
#   'paragraph',
#   '1',
#   'shall',
#   'regular',
#   'basi',
#   'less',
#   'year',
#   'inform',
#   'compet',
#   'author',
#   'member',
#   'state',
#   'use',
#   'made',
#   'paragraph',
#   '1',
#   'circumst',
#   'arrang',
#   'refer',
#   'paragraph',
#   '2',
#   'subsidiari',
#   'third',
#   'countri',
#   'compet',
#   'author',
#   'shall',
#   'provid',
#   'inform',
#   'compet',
#   'author',
#   'third',
#   'countri',
#   'well'],
#  ['1',
#   'compet',
#   'author',
#   'may',
#   'accord',
#   'nation',
#   'law',
#   'partial',
#   'fulli',
#   'waiv',
#   'applic',
#   'requir',
#   'set',
#   'part',
#   'two',
#   'eight',
#   'one',
#   'credit',
#   'institut',
#   'situat',
#   'member',
#   'state',
#   'perman',
#   'affili',
#   'central',
#   'bodi',
#   'supervis',
#   'establish',
#   'member',
#   'state',
#   'follow',
#   'condit',
#   'met',
#   'commit',
#   'central',
#   'bodi',
#   'affili',
#   'institut',
#   'joint',
#   'sever',
#   'liabil',
#   'commit',
#   'affili',
#   'institut',
#   'entir',
#   'guarante',
#   'central',
#   'bodi',
#   'b',
#   'solvenc',
#   'liquid',
#   'central',
#   'bodi',
#   'affili',
#   'institut',
#   'monitor',
#   'whole',
#   'basi',
#   'consolid',
#   'account',
#   'institut',
#   'c',
#   'manag',
#   'central',
#   'bodi',
#   'empow',
#   'issu',
#   'instruct',
#   'manag',
#   'affili',
#   'institut',
#   'member',
#   'state',
#   'may',
#   'maintain',
#   'make',
#   'use',
#   'exist',
#   'nation',
#   'legisl',
#   'regard',
#   'applic',
#   'waiver',
#   'refer',
#   'first',
#   'subparagraph',
#   'long',
#   'conflict',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '2',
#   'compet',
#   'author',
#   'satisfi',
#   'condit',
#   'set',
#   'paragraph',
#   '1',
#   'met',
#   'liabil',
#   'commit',
#   'central',
#   'bodi',
#   'entir',
#   'guarante',
#   'affili',
#   'institut',
#   'compet',
#   'author',
#   'may',
#   'waiv',
#   'applic',
#   'part',
#   'two',
#   'eight',
#   'central',
#   'bodi',
#   'individu',
#   'basi'],
#  ['1',
#   'parent',
#   'institut',
#   'member',
#   'state',
#   'shall',
#   'compli',
#   'extent',
#   'manner',
#   'prescrib',
#   'oblig',
#   'laid',
#   'part',
#   'two',
#   'four',
#   'part',
#   'seven',
#   'basi',
#   'consolid',
#   'situat',
#   'parent',
#   'undertak',
#   'subsidiari',
#   'subject',
#   'regul',
#   'shall',
#   'set',
#   'proper',
#   'organis',
#   'structur',
#   'appropri',
#   'intern',
#   'control',
#   'mechan',
#   'order',
#   'ensur',
#   'data',
#   'requir',
#   'consolid',
#   'duli',
#   'process',
#   'forward',
#   'particular',
#   'shall',
#   'ensur',
#   'subsidiari',
#   'subject',
#   'regul',
#   'implement',
#   'arrang',
#   'process',
#   'mechan',
#   'ensur',
#   'proper',
#   'consolid',
#   '2',
#   'institut',
#   'control',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'shall',
#   'compli',
#   'extent',
#   'manner',
#   'prescrib',
#   'oblig',
#   'laid',
#   'part',
#   'two',
#   'four',
#   'part',
#   'seven',
#   'basi',
#   'consolid',
#   'situat',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'one',
#   'institut',
#   'control',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'first',
#   'subparagraph',
#   'shall',
#   'appli',
#   'institut',
#   'supervis',
#   'consolid',
#   'basi',
#   'appli',
#   'accord',
#   'articl',
#   '111',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   '3',
#   'eu',
#   'parent',
#   'institut',
#   'institut',
#   'control',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'institut',
#   'control',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'six',
#   'basi',
#   'consolid',
#   'situat',
#   'parent',
#   'institut',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'group',
#   'compris',
#   'one',
#   'credit',
#   'institut',
#   'invest',
#   'firm',
#   'authoris',
#   'provid',
#   'invest',
#   'servic',
#   'activ',
#   'list',
#   'point',
#   '3',
#   '6',
#   'section',
#   'annex',
#   'direct',
#   '2004',
#   '39',
#   'ec',
#   'pend',
#   'report',
#   'commiss',
#   'accord',
#   'group',
#   'compris',
#   'invest',
#   'firm',
#   'compet',
#   'author',
#   'may',
#   'exempt',
#   'invest',
#   'firm',
#   'complianc',
#   'oblig',
#   'laid',
#   'part',
#   'six',
#   'consolid',
#   'basi',
#   'take',
#   'account',
#   'natur',
#   'scale',
#   'complex',
#   'invest',
#   'firm',
#   'activ',
#   '4',
#   'appli',
#   'central',
#   'bodi',
#   'refer',
#   'compli',
#   'requir',
#   'part',
#   'two',
#   'eight',
#   'basi',
#   'consolid',
#   'situat',
#   'whole',
#   'constitut',
#   'central',
#   'bodi',
#   'togeth',
#   'affili',
#   'institut',
#   '5',
#   'addit',
#   'requir',
#   'paragraph',
#   '1',
#   '4',
#   'without',
#   'prejudic',
#   'provis',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'justifi',
#   'supervisori',
#   'purpos',
#   'specif',
#   'risk',
#   'capit',
#   'structur',
#   'institut',
#   'member',
#   'state',
#   'adopt',
#   'nation',
#   'law',
#   'requir',
#   'structur',
#   'separ',
#   'activ',
#   'within',
#   'bank',
#   'group',
#   'compet',
#   'author',
#   'may',
#   'requir',
#   'structur',
#   'separ',
#   'institut',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'two',
#   'four',
#   'part',
#   'six',
#   'eight',
#   'regul',
#   'titl',
#   'vii',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'sub',
#   'consolid',
#   'basi',
#   'appli',
#   'approach',
#   'set',
#   'first',
#   'subparagraph',
#   'shall',
#   'without',
#   'prejudic',
#   'effect',
#   'supervis',
#   'consolid',
#   'basi',
#   'shall',
#   'neither',
#   'entail',
#   'disproportion',
#   'advers',
#   'effect',
#   'whole',
#   'part',
#   'financi',
#   'system',
#   'member',
#   'state',
#   'union',
#   'whole',
#   'form',
#   'creat',
#   'obstacl',
#   'function',
#   'intern',
#   'market'],
#  ['financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'least',
#   'one',
#   'credit',
#   'institut',
#   'one',
#   'invest',
#   'firm',
#   'subsidiari',
#   'requir',
#   'appli',
#   'basi',
#   'consolid',
#   'situat',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'shall',
#   'appli',
#   'credit',
#   'institut'],
#  ['1',
#   'eu',
#   'parent',
#   'institut',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'eight',
#   'basi',
#   'consolid',
#   'situat',
#   'signific',
#   'subsidiari',
#   'eu',
#   'parent',
#   'institut',
#   'subsidiari',
#   'materi',
#   'signific',
#   'local',
#   'market',
#   'shall',
#   'disclos',
#   'inform',
#   'specifi',
#   'individu',
#   'sub',
#   'consolid',
#   'basi',
#   '2',
#   'institut',
#   'control',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'shall',
#   'compli',
#   'oblig',
#   'laid',
#   'part',
#   'eight',
#   'basi',
#   'consolid',
#   'situat',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'signific',
#   'subsidiari',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'hold',
#   'compani',
#   'subsidiari',
#   'materi',
#   'signific',
#   'local',
#   'market',
#   'shall',
#   'disclos',
#   'inform',
#   'specifi',
#   'individu',
#   'sub',
#   'consolid',
#   'basi',
#   '3',
#   'paragraph',
#   '1',
#   '2',
#   'shall',
#   'appli',
#   'full',
#   'part',
#   'eu',
#   'parent',
#   'institut',
#   'institut',
#   'control',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'extent',
#   'includ',
#   'within',
#   'equival',
#   'disclosur',
#   'provid',
#   'consolid',
#   'basi',
#   'parent',
#   'undertak',
#   'establish',
#   'third',
#   'countri',
#   '4',
#   'appli',
#   'central',
#   'bodi',
#   'refer',
#   'compli',
#   'requir',
#   'part',
#   'eight',
#   'basi',
#   'consolid',
#   'situat',
#   'central',
#   'bodi',
#   'shall',
#   'appli',
#   'central',
#   'bodi',
#   'affili',
#   'institut',
#   'shall',
#   'treat',
#   'subsidiari',
#   'central',
#   'bodi'],
#  ['1',
#   'parent',
#   'undertak',
#   'subsidiari',
#   'subject',
#   'regul',
#   'shall',
#   'meet',
#   'oblig',
#   'laid',
#   'part',
#   'five',
#   'consolid',
#   'sub',
#   'consolid',
#   'basi',
#   'ensur',
#   'arrang',
#   'process',
#   'mechan',
#   'requir',
#   'provis',
#   'consist',
#   'well',
#   'integr',
#   'data',
#   'inform',
#   'relev',
#   'purpos',
#   'supervis',
#   'produc',
#   'particular',
#   'shall',
#   'ensur',
#   'subsidiari',
#   'subject',
#   'regul',
#   'implement',
#   'arrang',
#   'process',
#   'mechan',
#   'ensur',
#   'complianc',
#   'provis',
#   '2',
#   'institut',
#   'shall',
#   'appli',
#   'addit',
#   'risk',
#   'weight',
#   'accord',
#   'appli',
#   'consolid',
#   'sub',
#   'consolid',
#   'basi',
#   'requir',
#   '406',
#   'breach',
#   'level',
#   'entiti',
#   'establish',
#   'third',
#   'countri',
#   'includ',
#   'consolid',
#   'accord',
#   'breach',
#   'materi',
#   'relat',
#   'overal',
#   'risk',
#   'profil',
#   'group',
#   '3',
#   'oblig',
#   'result',
#   'part',
#   'five',
#   'concern',
#   'subsidiari',
#   'subject',
#   'regul',
#   'shall',
#   'appli',
#   'eu',
#   'parent',
#   'institut',
#   'institut',
#   'control',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'demonstr',
#   'compet',
#   'author',
#   'applic',
#   'part',
#   'five',
#   'unlaw',
#   'law',
#   'third',
#   'countri',
#   'subsidiari',
#   'establish'],
#  ['1',
#   'consolid',
#   'supervisor',
#   'may',
#   'waiv',
#   'case',
#   'case',
#   'basi',
#   'applic',
#   'part',
#   'three',
#   'regul',
#   'titl',
#   'vii',
#   'chapter',
#   '4',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'consolid',
#   'basi',
#   'provid',
#   'follow',
#   'condit',
#   'exist',
#   'eu',
#   'invest',
#   'firm',
#   'group',
#   'use',
#   'altern',
#   'calcul',
#   'total',
#   'risk',
#   'exposur',
#   'amount',
#   'refer',
#   'b',
#   'invest',
#   'firm',
#   'group',
#   'fall',
#   'within',
#   'categori',
#   'c',
#   'eu',
#   'invest',
#   'firm',
#   'group',
#   'meet',
#   'requir',
#   'impos',
#   'individu',
#   'basi',
#   'time',
#   'deduct',
#   'common',
#   'equiti',
#   'tier',
#   '1',
#   'item',
#   'conting',
#   'liabil',
#   'favour',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'would',
#   'otherwis',
#   'consolid',
#   'financi',
#   'hold',
#   'compani',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'invest',
#   'firm',
#   'group',
#   'hold',
#   'least',
#   'much',
#   'capit',
#   'defin',
#   'sum',
#   'item',
#   'refer',
#   'cover',
#   'sum',
#   'follow',
#   'sum',
#   'full',
#   'book',
#   'valu',
#   'hold',
#   'subordin',
#   'claim',
#   'instrument',
#   'refer',
#   'h',
#   'c',
#   'c',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'would',
#   'otherwis',
#   'consolid',
#   'ii',
#   'total',
#   'amount',
#   'conting',
#   'liabil',
#   'favour',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'would',
#   'otherwis',
#   'consolid',
#   'e',
#   'group',
#   'includ',
#   'credit',
#   'institut',
#   'criteria',
#   'first',
#   'subparagraph',
#   'met',
#   'eu',
#   'invest',
#   'firm',
#   'shall',
#   'place',
#   'system',
#   'monitor',
#   'control',
#   'sourc',
#   'capit',
#   'fund',
#   'financi',
#   'hold',
#   'compani',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'within',
#   'group',
#   '2',
#   'compet',
#   'author',
#   'may',
#   'also',
#   'appli',
#   'waiver',
#   'financi',
#   'hold',
#   'compani',
#   'hold',
#   'lower',
#   'amount',
#   'fund',
#   'amount',
#   'calcul',
#   'paragraph',
#   '1',
#   'lower',
#   'sum',
#   'fund',
#   'requir',
#   'impos',
#   'individu',
#   'basi',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'would',
#   'otherwis',
#   'consolid',
#   'total',
#   'amount',
#   'conting',
#   'liabil',
#   'favour',
#   'invest',
#   'firm',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'would',
#   'otherwis',
#   'consolid',
#   'purpos',
#   'paragraph',
#   'fund',
#   'requir',
#   'invest',
#   'undertak',
#   'third',
#   'countri',
#   'financi',
#   'institut',
#   'asset',
#   'manag',
#   'compani',
#   'ancillari',
#   'servic',
#   'undertak',
#   'notion',
#   'fund',
#   'requir'],
#  ['entiti',
#   'group',
#   'invest',
#   'firm',
#   'includ',
#   'parent',
#   'entiti',
#   'invest',
#   'firm',
#   'exempt',
#   'applic',
#   'requir',
#   'laid',
#   'part',
#   'seven',
#   'individu',
#   'basi',
#   'accord',
#   'parent',
#   'invest',
#   'firm',
#   'may',
#   'choos',
#   'appli',
#   'requir',
#   'laid',
#   'part',
#   'seven',
#   'consolid',
#   'basi'],
#  ['1',
#   'invest',
#   'firm',
#   'group',
#   'grant',
#   'waiver',
#   'provid',
#   'shall',
#   'notifi',
#   'compet',
#   'author',
#   'risk',
#   'could',
#   'undermin',
#   'financi',
#   'posit',
#   'includ',
#   'associ',
#   'composit',
#   'sourc',
#   'fund',
#   'intern',
#   'capit',
#   'fund',
#   '2',
#   'compet',
#   'author',
#   'respons',
#   'prudenti',
#   'supervis',
#   'invest',
#   'firm',
#   'waiv',
#   'oblig',
#   'supervis',
#   'consolid',
#   'basi',
#   'provid',
#   'shall',
#   'take',
#   'appropri',
#   'measur',
#   'monitor',
#   'risk',
#   'notabl',
#   'larg',
#   'exposur',
#   'whole',
#   'group',
#   'includ',
#   'undertak',
#   'locat',
#   'member',
#   'state',
#   '3',
#   'compet',
#   'author',
#   'respons',
#   'prudenti',
#   'supervis',
#   'invest',
#   'firm',
#   'waiv',
#   'applic',
#   'fund',
#   'requir',
#   'consolid',
#   'basi',
#   'provid',
#   'requir',
#   'part',
#   'eight',
#   'shall',
#   'appli',
#   'individu',
#   'basi'],
#  ['1',
#   'institut',
#   'requir',
#   'compli',
#   'requir',
#   'refer',
#   'section',
#   '1',
#   'basi',
#   'consolid',
#   'situat',
#   'shall',
#   'carri',
#   'full',
#   'consolid',
#   'institut',
#   'financi',
#   'institut',
#   'subsidiari',
#   'relev',
#   'subsidiari',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'mix',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'paragraph',
#   '2',
#   '8',
#   'appli',
#   'part',
#   'six',
#   'appli',
#   'basi',
#   'institut',
#   'consolid',
#   'situat',
#   '2',
#   'howev',
#   'compet',
#   'author',
#   'may',
#   'case',
#   'case',
#   'basi',
#   'permit',
#   'proport',
#   'consolid',
#   'accord',
#   'share',
#   'capit',
#   'parent',
#   'undertak',
#   'hold',
#   'subsidiari',
#   'proport',
#   'consolid',
#   'may',
#   'permit',
#   'follow',
#   'condit',
#   'fulfil',
#   'liabil',
#   'parent',
#   'undertak',
#   'limit',
#   'share',
#   'capit',
#   'parent',
#   'undertak',
#   'hold',
#   'subsidiari',
#   'view',
#   'liabil',
#   'sharehold',
#   'member',
#   'b',
#   'solvenc',
#   'sharehold',
#   'member',
#   'satisfactori',
#   'c',
#   'liabil',
#   'sharehold',
#   'member',
#   'clearli',
#   'establish',
#   'legal',
#   'bind',
#   'way',
#   '3',
#   'undertak',
#   'link',
#   'relationship',
#   'within',
#   'mean',
#   'articl',
#   '12',
#   '1',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'compet',
#   'author',
#   'shall',
#   'determin',
#   'consolid',
#   'carri',
#   '4',
#   'consolid',
#   'supervisor',
#   'shall',
#   'requir',
#   'proport',
#   'consolid',
#   'accord',
#   'share',
#   'capit',
#   'held',
#   'particip',
#   'institut',
#   'financi',
#   'institut',
#   'manag',
#   'undertak',
#   'includ',
#   'consolid',
#   'togeth',
#   'one',
#   'undertak',
#   'includ',
#   'consolid',
#   'undertak',
#   'liabil',
#   'limit',
#   'share',
#   'capit',
#   'hold',
#   '5',
#   'case',
#   'particip',
#   'capit',
#   'tie',
#   'refer',
#   'paragraph',
#   '1',
#   '2',
#   'compet',
#   'author',
#   'shall',
#   'determin',
#   'whether',
#   'consolid',
#   'carri',
#   'particular',
#   'may',
#   'permit',
#   'requir',
#   'use',
#   'equiti',
#   'method',
#   'method',
#   'shall',
#   'howev',
#   'constitut',
#   'inclus',
#   'undertak',
#   'concern',
#   'supervis',
#   'consolid',
#   'basi',
#   '6',
#   'compet',
#   'author',
#   'shall',
#   'determin',
#   'whether',
#   'consolid',
#   'carri',
#   'follow',
#   'case',
#   'opinion',
#   'compet',
#   'author',
#   'institut',
#   'exercis',
#   'signific',
#   'influenc',
#   'one',
#   'institut',
#   'financi',
#   'institut',
#   'without',
#   'hold',
#   'particip',
#   'capit',
#   'tie',
#   'institut',
#   'b',
#   'two',
#   'institut',
#   'financi',
#   'institut',
#   'place',
#   'singl',
#   'manag',
#   'pursuant',
#   'contract',
#   'claus',
#   'memoranda',
#   'associ',
#   'particular',
#   'compet',
#   'author',
#   'may',
#   'permit',
#   'requir',
#   'use',
#   'method',
#   'provid',
#   'articl',
#   '12',
#   'direct',
#   '83',
#   '349',
#   'eec',
#   'method',
#   'shall',
#   'howev',
#   'constitut',
#   'inclus',
#   'undertak',
#   'concern',
#   'consolid',
#   'supervis',
#   '7',
#   'eba',
#   'shall',
#   'develop',
#   'draft',
#   'regulatori',
#   'technic',
#   'standard',
#   'specifi',
#   'condit',
#   'accord',
#   'consolid',
#   'shall',
#   'carri',
#   'case',
#   'refer',
#   'paragraph',
#   '2',
#   '6',
#   'shall',
#   'submit',
#   'draft',
#   'regulatori',
#   'technic',
#   'standard',
#   'commiss',
#   '31',
#   'decemb',
#   '2016',
#   'power',
#   'deleg',
#   'commiss',
#   'adopt',
#   'regulatori',
#   'technic',
#   'standard',
#   'refer',
#   'first',
#   'subparagraph',
#   'accord',
#   '14',
#   'regul',
#   'eu',
#   '1093',
#   '2010',
#   '8',
#   'consolid',
#   'supervis',
#   'requir',
#   'pursuant',
#   'articl',
#   '111',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'ancillari',
#   'servic',
#   'undertak',
#   'asset',
#   'manag',
#   'compani',
#   'defin',
#   'point',
#   '5',
#   'articl',
#   '2',
#   'direct',
#   '2002',
#   '87',
#   'ec',
#   'shall',
#   'includ',
#   'consolid',
#   'case',
#   'accord',
#   'method',
#   'laid',
#   'articl'],
#  ['1',
#   'institut',
#   'financi',
#   'institut',
#   'ancillari',
#   'servic',
#   'undertak',
#   'subsidiari',
#   'undertak',
#   'particip',
#   'held',
#   'need',
#   'includ',
#   'consolid',
#   'total',
#   'amount',
#   'asset',
#   'balanc',
#   'sheet',
#   'item',
#   'undertak',
#   'concern',
#   'less',
#   'smaller',
#   'follow',
#   'two',
#   'amount',
#   'eur',
#   '10',
#   'million',
#   'b',
#   '1',
#   'total',
#   'amount',
#   'asset',
#   'balanc',
#   'sheet',
#   'item',
#   'parent',
#   'undertak',
#   'undertak',
#   'hold',
#   'particip',
#   '2',
#   'compet',
#   'author',
#   'respons',
#   'exercis',
#   'supervis',
#   'consolid',
#   'basi',
#   'pursuant',
#   'articl',
#   '111',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'may',
#   'case',
#   'case',
#   'basi',
#   'decid',
#   'follow',
#   'case',
#   'institut',
#   'financi',
#   'institut',
#   'ancillari',
#   'servic',
#   'undertak',
#   'subsidiari',
#   'particip',
#   'held',
#   'need',
#   'includ',
#   'consolid',
#   'undertak',
#   'concern',
#   'situat',
#   'third',
#   'countri',
#   'legal',
#   'impedi',
#   'transfer',
#   'necessari',
#   'inform',
#   'b',
#   'undertak',
#   'concern',
#   'neglig',
#   'interest',
#   'respect',
#   'object',
#   'monitor',
#   'credit',
#   'institut',
#   'c',
#   'opinion',
#   'compet',
#   'author',
#   'respons',
#   'exercis',
#   'supervis',
#   'consolid',
#   'basi',
#   'consolid',
#   'financi',
#   'situat',
#   'undertak',
#   'concern',
#   'would',
#   'inappropri',
#   'mislead',
#   'far',
#   'object',
#   'supervis',
#   'credit',
#   'institut',
#   'concern',
#   '3',
#   'case',
#   'refer',
#   'paragraph',
#   '1',
#   'point',
#   'b',
#   'paragraph',
#   '2',
#   'sever',
#   'undertak',
#   'meet',
#   'criteria',
#   'set',
#   'therein',
#   'shall',
#   'nevertheless',
#   'includ',
#   'consolid',
#   'collect',
#   'non',
#   'neglig',
#   'interest',
#   'respect',
#   'specifi',
#   'object'],
#  ['1',
#   'compet',
#   'author',
#   'shall',
#   'work',
#   'togeth',
#   'full',
#   'consult',
#   'case',
#   'applic',
#   'permiss',
#   'refer',
#   '151',
#   '4',
#   '9',
#   '312',
#   '2',
#   'article363',
#   'respect',
#   'submit',
#   'eu',
#   'parent',
#   'institut',
#   'subsidiari',
#   'jointli',
#   'subsidiari',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'decid',
#   'whether',
#   'grant',
#   'permiss',
#   'sought',
#   'determin',
#   'term',
#   'condit',
#   'permiss',
#   'subject',
#   'b',
#   'purpos',
#   'determin',
#   'whether',
#   'criteria',
#   'specif',
#   'intragroup',
#   'treatment',
#   'refer',
#   '425',
#   '5',
#   'complement',
#   'eba',
#   'regulatori',
#   'technic',
#   'standard',
#   'refer',
#   '425',
#   '6',
#   'met',
#   'applic',
#   'shall',
#   'submit',
#   'consolid',
#   'supervisor',
#   'applic',
#   'refer',
#   'includ',
#   'descript',
#   'methodolog',
#   'use',
#   'alloc',
#   'oper',
#   'risk',
#   'capit',
#   'differ',
#   'entiti',
#   'group',
#   'applic',
#   'shall',
#   'indic',
#   'whether',
#   'diversif',
#   'effect',
#   'intend',
#   'factor',
#   'risk',
#   'measur',
#   'system',
#   '2',
#   'compet',
#   'author',
#   'shall',
#   'everyth',
#   'within',
#   'power',
#   'reach',
#   'joint',
#   'decis',
#   'within',
#   'six',
#   'month',
#   'applic',
#   'refer',
#   'point',
#   'paragraph',
#   '1',
#   'b',
#   'assess',
#   'criteria',
#   'determin',
#   'specif',
#   'treatment',
#   'refer',
#   'point',
#   'b',
#   'paragraph',
#   '1',
#   'joint',
#   'decis',
#   'shall',
#   'set',
#   'document',
#   'contain',
#   'fulli',
#   'reason',
#   'decis',
#   'shall',
#   'provid',
#   'applic',
#   'compet',
#   'author',
#   'refer',
#   'paragraph',
#   '1',
#   '3',
#   'period',
#   'refer',
#   'paragraph',
#   '2',
#   'shall',
#   'begin',
#   'date',
#   'receipt',
#   'complet',
#   'applic',
#   'refer',
#   'point',
#   'paragraph',
#   '1',
#   'consolid',
#   'supervisor',
#   'consolid',
#   'supervisor',
#   'shall',
#   'forward',
#   'complet',
#   'applic',
#   'compet',
#   'author',
#   'without',
#   'delay',
#   'b',
#   'date',
#   'receipt',
#   'compet',
#   'author',
#   'report',
#   'prepar',
#   'consolid',
#   'supervisor',
#   'analys',
#   'intragroup',
#   'commit',
#   'within',
#   'group',
#   '4',
#   'absenc',
#   'joint',
#   'decis',
#   'compet',
#   'author',
#   'within',
#   'six',
#   'month',
#   'consolid',
#   'supervisor',
#   'shall',
#   'make',
#   'decis',
#   'point',
#   'paragraph',
#   '1',
#   'decis',
#   'consolid',
#   'supervisor',
#   'shall',
#   'limit',
#   'power',
#   'compet',
#   'author',
#   'articl',
#   '105',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'decis',
#   'shall',
#   'set',
#   'document',
#   'contain',
#   'fulli',
#   'reason',
#   'decis',
#   'shall',
#   'take',
#   'account',
#   'view',
#   'reserv',
#   'compet',
#   'author',
#   'express',
#   'six',
#   'month',
#   'period',
#   'decis',
#   'shall',
#   'provid',
#   'eu',
#   'parent',
#   'institut',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'compet',
#   'author',
#   'consolid',
#   'supervisor',
#   'end',
#   'six',
#   'month',
#   'period',
#   'compet',
#   'author',
#   'concern',
#   'refer',
#   'matter',
#   'eba',
#   'accord',
#   'articl',
#   '19',
#   'regul',
#   'eu',
#   '1093',
#   '2010',
#   'consolid',
#   'supervisor',
#   'shall',
#   'defer',
#   'decis',
#   'point',
#   'paragraph',
#   '1',
#   'await',
#   'decis',
#   'eba',
#   'may',
#   'take',
#   'accord',
#   'articl',
#   '19',
#   '3',
#   'regul',
#   'decis',
#   'shall',
#   'take',
#   'decis',
#   'conform',
#   'decis',
#   'eba',
#   'six',
#   'month',
#   'period',
#   'shall',
#   'deem',
#   'concili',
#   'period',
#   'within',
#   'mean',
#   'regul',
#   'eba',
#   'shall',
#   'take',
#   'decis',
#   'within',
#   'one',
#   'month',
#   'matter',
#   'shall',
#   'refer',
#   'eba',
#   'end',
#   'six',
#   'month',
#   'period',
#   'joint',
#   'decis',
#   'reach',
#   '5',
#   'absenc',
#   'joint',
#   'decis',
#   'compet',
#   'author',
#   'within',
#   'six',
#   'month',
#   'compet',
#   'author',
#   'respons',
#   'supervis',
#   'subsidiari',
#   'individu',
#   'basi',
#   'shall',
#   'make',
#   'decis',
#   'point',
#   'b',
#   'paragraph',
#   '1',
#   'decis',
#   'shall',
#   'set',
#   'document',
#   'contain',
#   'fulli',
#   'reason',
#   'decis',
#   'shall',
#   'take',
#   'account',
#   'view',
#   'reserv',
#   'compet',
#   'author',
#   'express',
#   'six',
#   'month',
#   'period',
#   'decis',
#   'shall',
#   'provid',
#   'consolid',
#   'supervisor',
#   'inform',
#   'eu',
#   'parent',
#   'institut',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'end',
#   'six',
#   'month',
#   'period',
#   'consolid',
#   'supervisor',
#   'refer',
#   'matter',
#   'eba',
#   'accord',
#   'articl',
#   '19',
#   'regul',
#   'eu',
#   '1093',
#   '2010',
#   'compet',
#   'author',
#   'respons',
#   'supervis',
#   'subsidiari',
#   'individu',
#   'basi',
#   'shall',
#   'defer',
#   'decis',
#   'point',
#   'b',
#   'paragraph',
#   '1',
#   'await',
#   'decis',
#   'eba',
#   'may',
#   'take',
#   'accord',
#   'articl',
#   '19',
#   '3',
#   'regul',
#   'decis',
#   'shall',
#   'take',
#   'decis',
#   'conform',
#   'decis',
#   'eba',
#   'six',
#   'month',
#   'period',
#   'shall',
#   'deem',
#   'concili',
#   'period',
#   'within',
#   'mean',
#   'regul',
#   'eba',
#   'shall',
#   'take',
#   'decis',
#   'within',
#   'one',
#   'month',
#   'matter',
#   'shall',
#   'refer',
#   'eba',
#   'end',
#   'six',
#   'month',
#   'period',
#   'joint',
#   'decis',
#   'reach',
#   '6',
#   'eu',
#   'parent',
#   'institut',
#   'subsidiari',
#   'subsidiari',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'use',
#   'advanc',
#   'measur',
#   'approach',
#   'refer',
#   'irb',
#   'approach',
#   'refer',
#   'unifi',
#   'basi',
#   'compet',
#   'author',
#   'shall',
#   'allow',
#   'qualifi',
#   'criteria',
#   'set',
#   'part',
#   'three',
#   'titl',
#   'ii',
#   'chapter',
#   '3',
#   'section',
#   '6',
#   'respect',
#   'met',
#   'parent',
#   'subsidiari',
#   'consid',
#   'togeth',
#   'way',
#   'consist',
#   'structur',
#   'group',
#   'risk',
#   'manag',
#   'system',
#   'process',
#   'methodolog',
#   '7',
#   'decis',
#   'refer',
#   'paragraph',
#   '2',
#   '4',
#   '5',
#   'shall',
#   'recognis',
#   'determin',
#   'appli',
#   'compet',
#   'author',
#   'member',
#   'state',
#   'concern',
#   '8',
#   'eba',
#   'shall',
#   'develop',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'specifi',
#   'joint',
#   'decis',
#   'process',
#   'refer',
#   'point',
#   'paragraph',
#   '1',
#   'regard',
#   'applic',
#   'permiss',
#   'refer',
#   '151',
#   '4',
#   '9',
#   '312',
#   '2',
#   'view',
#   'facilit',
#   'joint',
#   'decis',
#   'eba',
#   'shall',
#   'submit',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'commiss',
#   '31',
#   'decemb',
#   '2014',
#   'power',
#   'confer',
#   'commiss',
#   'adopt',
#   'implement',
#   'technic',
#   'standard',
#   'refer',
#   'first',
#   'subparagraph',
#   'accord',
#   'articl',
#   '15',
#   'regul',
#   'eu',
#   '1093',
#   '2010'],
#  ['1',
#   'upon',
#   'applic',
#   'eu',
#   'parent',
#   'institut',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'sub',
#   'consolid',
#   'subsidiari',
#   'eu',
#   'parent',
#   'institut',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'consolid',
#   'supervisor',
#   'compet',
#   'author',
#   'respons',
#   'supervis',
#   'subsidiari',
#   'eu',
#   'parent',
#   'institut',
#   'eu',
#   'parent',
#   'financi',
#   'hold',
#   'compani',
#   'eu',
#   'parent',
#   'mix',
#   'financi',
#   'hold',
#   'compani',
#   'member',
#   'state',
#   'shall',
#   'everyth',
#   'within',
#   'power',
#   'reach',
#   'joint',
#   'decis',
#   'whether',
#   'condit',
#   'point',
#   'met',
#   'identifi',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'applic',
#   'joint',
#   'decis',
#   'shall',
#   'reach',
#   'within',
#   'six',
#   'month',
#   'submiss',
#   'consolid',
#   'supervisor',
#   'report',
#   'identifi',
#   'singl',
#   'liquid',
#   'sub',
#   'group',
#   'basi',
#   'criteria',
#   'laid',
#   'event',
#   'disagr',
#   'six',
#   'month',
#   'period',
#   'consolid',
#   'supervisor',
#   'shall',
#   'consult',
#   'eba',
#   'request',
#   'compet',
#   'author',
#   'concern',
#   'consolid',
#   'supervisor',
#   'may',
#   'consult',
#   'eba',
#   'initi',
#   'joint',
#   'decis',
#   'may',
# ...
#   'counterparti',
#   'viii',
#   'cyclic',
#   'capit',
#   'measur',
#   'total',
#   'exposur',
#   'measur',
#   'leverag',
#   'ratio',
#   'ix',
#   'bank',
#   'lend',
#   'particular',
#   'focu',
#   'lend',
#   'sme',
#   'local',
#   'author',
#   'region',
#   'govern',
#   'public',
#   'sector',
#   'entiti',
#   'trade',
#   'financ',
#   'includ',
#   'lend',
#   'offici',
#   'export',
#   'credit',
#   'insur',
#   'scheme',
#   'b',
#   'interact',
#   'leverag',
#   'ratio',
#   'risk',
#   'base',
#   'fund',
#   'requir',
#   'liquid',
#   'requir',
#   'specifi',
#   'regul',
#   'c',
#   'impact',
#   'account',
#   'differ',
#   'account',
#   'standard',
#   'applic',
#   'regul',
#   'ec',
#   '1606',
#   '2002',
#   'account',
#   'standard',
#   'applic',
#   'direct',
#   '86',
#   '635',
#   'eec',
#   'applic',
#   'account',
#   'framework',
#   'relev',
#   'account',
#   'framework',
#   'compar',
#   'leverag',
#   'ratio'],
#  ['31',
#   'decemb',
#   '2014',
#   'commiss',
#   'shall',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'applic',
#   'effect',
#   'provis',
#   'part',
#   'five',
#   'light',
#   'intern',
#   'market',
#   'develop'],
#  ['1',
#   '30',
#   'june',
#   '2014',
#   'commiss',
#   'shall',
#   'consult',
#   'esrb',
#   'eba',
#   'review',
#   'whether',
#   'macroprudenti',
#   'rule',
#   'contain',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'suffici',
#   'mitig',
#   'system',
#   'risk',
#   'sector',
#   'region',
#   'member',
#   'state',
#   'includ',
#   'assess',
#   'whether',
#   'current',
#   'macroprudenti',
#   'tool',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'effect',
#   'effici',
#   'transpar',
#   'b',
#   'whether',
#   'coverag',
#   'possibl',
#   'degre',
#   'overlap',
#   'differ',
#   'macroprudenti',
#   'tool',
#   'target',
#   'similar',
#   'risk',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'adequ',
#   'appropri',
#   'propos',
#   'new',
#   'macroprudenti',
#   'rule',
#   'c',
#   'intern',
#   'agre',
#   'standard',
#   'system',
#   'institut',
#   'interact',
#   'provis',
#   'regul',
#   'direct',
#   '2013',
#   '36',
#   'eu',
#   'appropri',
#   'propos',
#   'new',
#   'rule',
#   'take',
#   'account',
#   'intern',
#   'agre',
#   'standard',
#   '2',
#   '31',
#   'decemb',
#   '2014',
#   'commiss',
#   'shall',
#   'basi',
#   'consult',
#   'esrb',
#   'eba',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'assess',
#   'refer',
#   'paragraph',
#   '1',
#   'appropri',
#   'submit',
#   'legisl',
#   'propos',
#   'european',
#   'parliament',
#   'council'],
#  ['31',
#   'decemb',
#   '2016',
#   'commiss',
#   'shall',
#   'review',
#   'report',
#   'applic',
#   'submit',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'appropri',
#   'legisl',
#   'propos'],
#  ['1',
#   'eba',
#   'togeth',
#   'esma',
#   'shall',
#   '2',
#   'januari',
#   '2015',
#   'report',
#   'function',
#   'regul',
#   'relat',
#   'oblig',
#   'regul',
#   'eu',
#   '648',
#   '2012',
#   'particular',
#   'regard',
#   'institut',
#   'oper',
#   'central',
#   'counterparti',
#   'order',
#   'avoid',
#   'duplic',
#   'requir',
#   'deriv',
#   'transact',
#   'therebi',
#   'avoid',
#   'increas',
#   'regulatori',
#   'risk',
#   'increas',
#   'cost',
#   'monitor',
#   'compet',
#   'author',
#   '2',
#   'eba',
#   'shall',
#   'monitor',
#   'evalu',
#   'oper',
#   'provis',
#   'fund',
#   'requir',
#   'exposur',
#   'central',
#   'counterparti',
#   'set',
#   'section',
#   '9',
#   'chapter',
#   '6',
#   'titl',
#   'ii',
#   'part',
#   'three',
#   '1',
#   'januari',
#   '2015',
#   'eba',
#   'shall',
#   'report',
#   'commiss',
#   'impact',
#   'effect',
#   'provis',
#   '3',
#   '31',
#   'decemb',
#   '2016',
#   'commiss',
#   'shall',
#   'review',
#   'report',
#   'reconcili',
#   'regul',
#   'relat',
#   'oblig',
#   'regul',
#   'eu',
#   '648',
#   '2012',
#   'fund',
#   'requir',
#   'set',
#   'section',
#   '9',
#   'chapter',
#   '6',
#   'titl',
#   'ii',
#   'part',
#   'three',
#   'shall',
#   'submit',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'appropri',
#   'legisl',
#   'propos'],
#  ['31',
#   'decemb',
#   '2015',
#   'commiss',
#   'shall',
#   'report',
#   'impact',
#   'regul',
#   'encourag',
#   'long',
#   'term',
#   'invest',
#   'growth',
#   'promot',
#   'infrastructur'],
#  ['31',
#   'decemb',
#   '2014',
#   'commiss',
#   'shall',
#   'review',
#   'report',
#   'appropri',
#   'definit',
#   'elig',
#   'capit',
#   'appli',
#   'purpos',
#   'titl',
#   'iii',
#   'part',
#   'two',
#   'part',
#   'four',
#   'shall',
#   'submit',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'appropri',
#   'legisl',
#   'propos'],
#  ['31',
#   'decemb',
#   '2015',
#   'commiss',
#   'shall',
#   'review',
#   'report',
#   'whether',
#   'regul',
#   'contain',
#   'requir',
#   'addit',
#   'tier',
#   '1',
#   'tier',
#   '2',
#   'capit',
#   'instrument',
#   'written',
#   'event',
#   'determin',
#   'institut',
#   'longer',
#   'viabl',
#   'commiss',
#   'shall',
#   'submit',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'togeth',
#   'legisl',
#   'propos',
#   'appropri'],
#  ['eba',
#   'shall',
#   '30',
#   'june',
#   '2014',
#   'prepar',
#   'report',
#   'whether',
#   'revis',
#   'ia',
#   '19',
#   'conjunct',
#   'deduct',
#   'net',
#   'pension',
#   'asset',
#   'set',
#   'e',
#   'chang',
#   'net',
#   'pension',
#   'liabil',
#   'lead',
#   'undu',
#   'volatil',
#   'institut',
#   'fund',
#   'take',
#   'account',
#   'eba',
#   'report',
#   'commiss',
#   'shall',
#   '31',
#   'decemb',
#   '2014',
#   'prepar',
#   'report',
#   'european',
#   'parliament',
#   'council',
#   'issu',
#   'refer',
#   'first',
#   'paragraph',
#   'togeth',
#   'legisl',
#   'propos',
#   'appropri',
#   'introduc',
#   'treatment',
#   'adjust',
#   'defin',
#   'net',
#   'benefit',
#   'pension',
#   'fund',
#   'asset',
#   'liabil',
#   'calcul',
#   'fund'],
#  ['regul',
#   'eu',
#   '648',
#   '2012',
#   'amend',
#   'follow',
#   '1',
#   'follow',
#   'chapter',
#   'ad',
#   'titl',
#   'iv'],
#  ['1',
#   'purpos',
#   'articl',
#   '308',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'european',
#   'parliament',
#   'council',
#   '26',
#   'june',
#   '2013',
#   'prudenti',
#   'requir',
#   'credit',
#   'institut',
#   'invest',
#   'firm',
#   '38',
#   'ccp',
#   'receiv',
#   'notif',
#   'refer',
#   'b',
#   'regul',
#   'shall',
#   'calcul',
#   'kccp',
#   'specifi',
#   'paragraph',
#   '2',
#   'contract',
#   'transact',
#   'clear',
#   'clear',
#   'member',
#   'fall',
#   'within',
#   'coverag',
#   'given',
#   'default',
#   'fund',
#   '2',
#   'ccp',
#   'shall',
#   'calcul',
#   'hypothet',
#   'capit',
#   'kccp',
#   'follow',
#   'ebrmi',
#   'exposur',
#   'valu',
#   'risk',
#   'mitig',
#   'equal',
#   'exposur',
#   'valu',
#   'ccp',
#   'clear',
#   'member',
#   'aris',
#   'contract',
#   'transact',
#   'clear',
#   'member',
#   'calcul',
#   'without',
#   'take',
#   'account',
#   'collater',
#   'post',
#   'clear',
#   'member',
#   'imi',
#   'initi',
#   'margin',
#   'post',
#   'ccp',
#   'clear',
#   'member',
#   'dfi',
#   'pre',
#   'fund',
#   'contribut',
#   'clear',
#   'member',
#   'rw',
#   'risk',
#   'weight',
#   '20',
#   'capit',
#   'ratio',
#   '8',
#   '3',
#   'ccp',
#   'shall',
#   'undertak',
#   'calcul',
#   'requir',
#   'paragraph',
#   '2',
#   'least',
#   'quarterli',
#   'frequent',
#   'requir',
#   'compet',
#   'author',
#   'clear',
#   'member',
#   'institut',
#   '4',
#   'eba',
#   'shall',
#   'develop',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'specifi',
#   'follow',
#   'purpos',
#   'paragraph',
#   '3',
#   'frequenc',
#   'date',
#   'calcul',
#   'laid',
#   'paragraph',
#   '2',
#   'b',
#   'situat',
#   'compet',
#   'author',
#   'institut',
#   'act',
#   'clear',
#   'member',
#   'may',
#   'requir',
#   'higher',
#   'frequenc',
#   'calcul',
#   'report',
#   'refer',
#   'point',
#   'eba',
#   'shall',
#   'submit',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'commiss',
#   '1',
#   'januari',
#   '2014',
#   'power',
#   'confer',
#   'commiss',
#   'adopt',
#   'implement',
#   'technic',
#   'standard',
#   'refer',
#   'first',
#   'subparagraph',
#   'accord',
#   'articl',
#   '15',
#   'regul',
#   'eu',
#   '1093',
#   '2010'],
#  ['purpos',
#   'calcul',
#   'laid',
#   'follow',
#   'shall',
#   'appli',
#   'ccp',
#   'shall',
#   'calcul',
#   'valu',
#   'exposur',
#   'clear',
#   'member',
#   'follow',
#   'exposur',
#   'aris',
#   'contract',
#   'transact',
#   'list',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'ii',
#   'exposur',
#   'aris',
#   'contract',
#   'transact',
#   'list',
#   'b',
#   'c',
#   'e',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'shall',
#   'calcul',
#   'accord',
#   'financi',
#   'collater',
#   'comprehens',
#   'method',
#   'specifi',
#   'articl',
#   '223',
#   'regul',
#   'supervisori',
#   'volatil',
#   'adjust',
#   'specifi',
#   'articl',
#   '223',
#   '224',
#   'regul',
#   'except',
#   'set',
#   'point',
#   'articl',
#   '285',
#   '3',
#   'regul',
#   'shall',
#   'appli',
#   'iii',
#   'exposur',
#   'aris',
#   'transact',
#   'list',
#   'articl',
#   '301',
#   '1',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'entail',
#   'settlement',
#   'risk',
#   'shall',
#   'calcul',
#   'accord',
#   'part',
#   'three',
#   'titl',
#   'v',
#   'regul',
#   'b',
#   'institut',
#   'fall',
#   'scope',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'net',
#   'set',
#   'defin',
#   'part',
#   'three',
#   'titl',
#   'ii',
#   'regul',
#   'c',
#   'calcul',
#   'valu',
#   'refer',
#   'point',
#   'ccp',
#   'shall',
#   'subtract',
#   'exposur',
#   'collater',
#   'post',
#   'clear',
#   'member',
#   'appropri',
#   'reduc',
#   'supervisori',
#   'volatil',
#   'adjust',
#   'accord',
#   'financi',
#   'collater',
#   'comprehens',
#   'method',
#   'specifi',
#   'articl',
#   '224',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'ccp',
#   'shall',
#   'calcul',
#   'secur',
#   'financ',
#   'transact',
#   'exposur',
#   'clear',
#   'member',
#   'accord',
#   'financi',
#   'collater',
#   'comprehens',
#   'method',
#   'supervisori',
#   'volatil',
#   'adjust',
#   'specifi',
#   'articl',
#   '223',
#   '224',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'e',
#   'ccp',
#   'exposur',
#   'one',
#   'ccp',
#   'shall',
#   'treat',
#   'exposur',
#   'exposur',
#   'clear',
#   'member',
#   'includ',
#   'margin',
#   'pre',
#   'fund',
#   'contribut',
#   'receiv',
#   'ccp',
#   'calcul',
#   'kccp',
#   'f',
#   'ccp',
#   'place',
#   'bind',
#   'contractu',
#   'arrang',
#   'clear',
#   'member',
#   'allow',
#   'use',
#   'part',
#   'initi',
#   'margin',
#   'receiv',
#   'clear',
#   'member',
#   'pre',
#   'fund',
#   'contribut',
#   'ccp',
#   'shall',
#   'consid',
#   'initi',
#   'margin',
#   'prefund',
#   'contribut',
#   'purpos',
#   'calcul',
#   'paragraph',
#   '1',
#   'initi',
#   'margin',
#   'g',
#   'appli',
#   'mark',
#   'market',
#   'method',
#   'ccp',
#   'shall',
#   'replac',
#   'formula',
#   'point',
#   'c',
#   'ii',
#   'articl',
#   '298',
#   '1',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'follow',
#   'numer',
#   'ngr',
#   'calcul',
#   'accord',
#   'articl',
#   '274',
#   '1',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'variat',
#   'margin',
#   'actual',
#   'exchang',
#   'end',
#   'settlement',
#   'period',
#   'denomin',
#   'gross',
#   'replac',
#   'cost',
#   'h',
#   'appli',
#   'mark',
#   'market',
#   'method',
#   'set',
#   'articl',
#   '274',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'ccp',
#   'shall',
#   'replac',
#   'formula',
#   'point',
#   'c',
#   'ii',
#   'articl',
#   '298',
#   '1',
#   'regul',
#   'follow',
#   'numer',
#   'ngr',
#   'calcul',
#   'accord',
#   'articl',
#   '274',
#   '1',
#   'regul',
#   'variat',
#   'margin',
#   'actual',
#   'exchang',
#   'end',
#   'settlement',
#   'period',
#   'denomin',
#   'gross',
#   'replac',
#   'cost',
#   'ccp',
#   'cannot',
#   'calcul',
#   'valu',
#   'ngr',
#   'set',
#   'point',
#   'c',
#   'ii',
#   'articl',
#   '298',
#   '1',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'shall',
#   'notifi',
#   'clear',
#   'member',
#   'institut',
#   'compet',
#   'author',
#   'inabl',
#   'calcul',
#   'ngr',
#   'reason',
#   'unabl',
#   'carri',
#   'calcul',
#   'ii',
#   'period',
#   'three',
#   'month',
#   'may',
#   'use',
#   'valu',
#   'ngr',
#   '0',
#   '3',
#   'perform',
#   'calcul',
#   'pcere',
#   'specifi',
#   'point',
#   'g',
#   'j',
#   'end',
#   'period',
#   'specifi',
#   'point',
#   'ii',
#   'point',
#   'ccp',
#   'would',
#   'still',
#   'unabl',
#   'calcul',
#   'valu',
#   'ngr',
#   'shall',
#   'follow',
#   'stop',
#   'calcul',
#   'kccp',
#   'ii',
#   'notifi',
#   'clear',
#   'member',
#   'institut',
#   'compet',
#   'author',
#   'stop',
#   'calcul',
#   'kccp',
#   'k',
#   'l',
#   'ccp',
#   'one',
#   'default',
#   'fund',
#   'shall',
#   'carri',
#   'calcul',
#   'laid',
#   'default',
#   'fund',
#   'separ'],
#  ['1',
#   'purpos',
#   'articl',
#   '308',
#   'regul',
#   'eu',
#   '575',
#   '2013',
#   'ccp',
#   'shall',
#   'report',
#   'follow',
#   'inform',
#   'clear',
#   'member',
#   'institut',
#   'compet',
#   'author',
#   'hypothet',
#   'capit',
#   'kccp',
#   'b',
#   'sum',
#   'pre',
#   'fund',
#   'contribut',
#   'dfcm',
#   'c',
#   'amount',
#   'pre',
#   'fund',
#   'financi',
#   'resourc',
#   'requir',
#   'use',
#   'law',
#   'due',
#   'contractu',
#   'agreement',
#   'clear',
#   'member',
#   'cover',
#   'loss',
#   'follow',
#   'default',
#   'one',
#   'clear',
#   'member',
#   'use',
#   'default',
#   'fund',
#   'contribut',
#   'remain',
#   'clear',
#   'member',
#   'dfccp',
#   'total',
#   'number',
#   'clear',
#   'member',
#   'n',
#   'e',
#   'concentr',
#   'factor',
#   'β',
#   'set',
#   'f',
#   'ccp',
#   'one',
#   'default',
#   'fund',
#   'shall',
#   'report',
#   'inform',
#   'first',
#   'subparagraph',
#   'default',
#   'fund',
#   'separ',
#   '2',
#   'ccp',
#   'shall',
#   'notifi',
#   'clear',
#   'member',
#   'institut',
#   'least',
#   'quarterli',
#   'frequent',
#   'requir',
#   'compet',
#   'author',
#   'clear',
#   'member',
#   '3',
#   'eba',
#   'shall',
#   'develop',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'specifi',
#   'follow',
#   'uniform',
#   'templat',
#   'purpos',
#   'report',
#   'specifi',
#   'paragraph',
#   '1',
#   'b',
#   'frequenc',
#   'date',
#   'report',
#   'specifi',
#   'paragraph',
#   '2',
#   'c',
#   'situat',
#   'compet',
#   'author',
#   'institut',
#   'act',
#   'clear',
#   'member',
#   'may',
#   'requir',
#   'higher',
#   'frequenc',
#   'report',
#   'refer',
#   'point',
#   'b',
#   'eba',
#   'shall',
#   'submit',
#   'draft',
#   'implement',
#   'technic',
#   'standard',
#   'commiss',
#   '1',
#   'januari',
#   '2014',
#   'power',
#   'confer',
#   'commiss',
#   'adopt',
#   'implement',
#   'technic',
#   'standard',
#   'refer',
#   'first',
#   'subparagraph',
#   'accord',
#   'articl',
#   '15',
#   'regul',
#   'eu',
#   '1093',
#   '2010'],
#  ['purpos',
#   'follow',
#   'shall',
#   'appli',
#   'rule',
#   'ccp',
#   'provid',
#   'use',
#   'part',
#   'financi',
#   'resourc',
#   'parallel',
#   'pre',
#   'fund',
#   'contribut',
#   'clear',
#   'member',
#   'manner',
#   'make',
#   'resourc',
#   'equival',
#   'pre',
#   'fund',
#   'contribut',
#   'clear',
#   'member',
#   'term',
#   'absorb',
#   'loss',
#   'incur',
#   'ccp',
#   'case',
#   'default',
#   'insolv',
#   'one',
#   'clear',
#   'member',
#   'ccp',
#   'shall',
#   'add',
#   'correspond',
#   'amount',
#   'resourc',
#   'dfcm',
#   'b',
#   'c',
#   'ccp',
#   'shall',
#   'calcul',
#   'concentr',
#   'factor',
#   'β',
#   'accord',
#   'follow',
#   'formula',
#   'pcere',
#   'reduc',
#   'figur',
#   'potenti',
#   'futur',
#   'credit',
#   'exposur',
#   'contract',
#   'transact',
#   'ccp',
#   'clear',
#   'member',
#   'pcere',
#   '1',
#   'reduc',
#   'figur',
#   'potenti',
#   'futur',
#   'credit',
#   'exposur',
#   'contract',
#   'transact',
#   'ccp',
#   'clear',
#   'member',
#   'largest',
#   'pcere',
#   'valu',
#   'pcere',
#   '2',
#   'reduc',
#   'figur',
#   'potenti',
#   'futur',
#   'credit',
#   'exposur',
#   'contract',
#   'transact',
#   'ccp',
#   'clear',
#   'member',
#   'second',
#   'largest',
#   'pcere',
#   'valu',
#   '2',
#   'b',
#   'delet',
#   '3',
#   'follow',
#   'paragraph',
#   'insert',
#   '5a',
#   '15',
#   'month',
#   'date',
#   'entri',
#   'forc',
#   'latest',
#   'eleven',
#   'regulatori',
#   'technic',
#   'standard',
#   'refer',
#   'end',
#   'first',
#   'subparagraph',
#   'paragraph',
#   '3',
#   'decis',
#   'made',
#   'authoris',
#   'ccp',
#   'whichev',
#   'date',
#   'earlier',
#   'ccp',
#   'shall',
#   'appli',
#   'treatment',
#   'specifi',
#   'third',
#   'subparagraph',
#   'paragraph',
#   '15',
#   'month',
#   'date',
#   'entri',
#   'forc',
#   'latest',
#   'eleven',
#   'regulatori',
#   'technic',
#   'standard',
#   'refer',
#   'end',
#   'second',
#   'subparagraph',
#   'paragraph',
#   '3',
#   'decis',
#   'made',
#   'recognit',
#   'ccp',
#   'whichev',
#   'date',
#   'earlier',
#   'ccp',
#   'shall',
#   'appli',
#   'treatment',
#   'specifi',
#   'third',
#   'subparagraph',
#   'paragraph',
#   'ccp',
#   'default',
#   'fund',
#   'place',
#   'bind',
#   'arrang',
#   'clear',
#   'member',
#   'allow',
#   'use',
#   'part',
#   'initi',
#   'margin',
#   'receiv',
#   'clear',
#   'member',
#   'pre',
#   'fund',
#   'contribut',
#   'inform',
#   'shall',
#   'report',
#   'accord',
#   'shall',
#   'includ',
#   'total',
#   'amount',
#   'initi',
#   'margin',
#   'receiv',
#   'clear',
#   'member',
#   'im',
#   'deadlin',
#   'first',
#   'second',
#   'subparagraph',
#   'paragraph',
#   'may',
#   'extend',
#   'addit',
#   'six',
#   'month',
#   'commiss',
#   'adopt',
#   'implement',
#   'act',
#   'refer',
#   'articl',
#   '497',
#   '3',
#   'regul',
#   'eu',
#   '575',
#   '2013']]

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=100, id2word = dictionary, passes=20)

# %%
print(ldamodel)
# Out:
# LdaModel(num_terms=2442, num_topics=100, decay=0.5, chunksize=2000)

# %%
ldamodel.print_topics(10)
# Out:
# [(29,
#   '0.062*"asset" + 0.056*"liquid" + 0.033*"high" + 0.025*"bank" + 0.020*"definit" + 0.019*"report" + 0.019*"credit" + 0.015*"c" + 0.014*"oper" + 0.014*"refer"'),
#  (18,
#   '0.110*"risk" + 0.080*"instrument" + 0.064*"debt" + 0.048*"posit" + 0.040*"shall" + 0.033*"requir" + 0.031*"payment" + 0.030*"fund" + 0.027*"underli" + 0.026*"calcul"'),
#  (89,
#   '0.090*"sheet" + 0.089*"balanc" + 0.062*"item" + 0.046*"valu" + 0.042*"annex" + 0.042*"exposur" + 0.041*"determin" + 0.030*"credit" + 0.029*"accord" + 0.028*"list"'),
#  (64,
#   '0.044*"exposur" + 0.034*"client" + 0.025*"shall" + 0.025*"institut" + 0.021*"calcul" + 0.017*"transact" + 0.014*"refer" + 0.012*"follow" + 0.011*"part" + 0.011*"titl"'),
#  (35,
#   '0.082*"requir" + 0.058*"fund" + 0.048*"1" + 0.044*"refer" + 0.044*"consolid" + 0.043*"subsidiari" + 0.038*"capit" + 0.030*"tier" + 0.027*"36" + 0.027*"direct"'),
#  (14,
#   '0.046*"hedg" + 0.041*"shall" + 0.034*"refer" + 0.033*"instrument" + 0.026*"set" + 0.018*"underli" + 0.018*"liquid" + 0.016*"default" + 0.015*"asset" + 0.013*"debt"'),
#  (24,
#   '0.000*"net" + 0.000*"requir" + 0.000*"shall" + 0.000*"contractu" + 0.000*"institut" + 0.000*"maintain" + 0.000*"b" + 0.000*"refer" + 0.000*"risk" + 0.000*"legal"'),
#  (59,
#   '0.054*"institut" + 0.043*"undertak" + 0.043*"hold" + 0.041*"financi" + 0.035*"consolid" + 0.035*"compani" + 0.024*"parent" + 0.017*"basi" + 0.015*"eu" + 0.014*"requir"'),
#  (6,
#   '0.081*"credit" + 0.068*"protect" + 0.037*"exposur" + 0.032*"shall" + 0.027*"institut" + 0.023*"applic" + 0.022*"elig" + 0.017*"take" + 0.017*"provid" + 0.015*"risk"'),
#  (9,
#   '0.050*"shall" + 0.048*"institut" + 0.015*"accord" + 0.011*"collater" + 0.010*"compet" + 0.010*"paragraph" + 0.010*"author" + 0.010*"materi" + 0.009*"eba" + 0.009*"asset"')]

# %%
lda_corpus = [max(prob,key=lambda y:y[1])
                for prob in ldamodel[corpus] ]
playlists = [[] for i in range(100)]
for i, x in enumerate(lda_corpus):
    playlists[x[0]].append(paragraphs[i])

# %%
docTopicProbMat = ldamodel.get_document_topics(corpus,minimum_probability=0)

# %%
listDocProb = list(docTopicProbMat)

# %%
probMatrix = np.zeros(shape=(len(df["Paragraphs"]),100))
for i,x in enumerate(listDocProb):      #each document i
    for t in x:     #each topic j
        probMatrix[i, t[0]] = t[1]

# %%
matrix = pd.DataFrame(probMatrix)

# %%
matrix
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.000119  0.000119  0.000119  0.000119  0.000119  0.000119  0.000119
# 1    0.000588  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588
# 2    0.000714  0.000714  0.000714  0.000714  0.000714  0.000714  0.000714
# 3    0.000003  0.012815  0.000003  0.000003  0.000003  0.000003  0.000003
# 4    0.000189  0.000189  0.000189  0.000189  0.000189  0.000189  0.000189
# 5    0.000078  0.000078  0.000078  0.000078  0.000078  0.000078  0.000078
# 6    0.000049  0.000049  0.000049  0.000049  0.000049  0.000049  0.000049
# 7    0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 8    0.000089  0.000089  0.000089  0.000089  0.000089  0.000089  0.000089
# 9    0.000081  0.000081  0.000081  0.000081  0.000081  0.000081  0.000081
# 10   0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 11   0.000312  0.000312  0.000312  0.000312  0.000312  0.000312  0.000312
# 12   0.000067  0.000067  0.000067  0.000067  0.000067  0.000067  0.000067
# 13   0.000087  0.000087  0.000087  0.000087  0.000087  0.000087  0.000087
# 14   0.000039  0.000039  0.000039  0.000039  0.000039  0.000039  0.000039
# 15   0.000323  0.000323  0.000323  0.000323  0.000323  0.000323  0.000323
# 16   0.000130  0.000130  0.000130  0.000130  0.000130  0.000130  0.000130
# 17   0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 18   0.000068  0.000068  0.000068  0.000068  0.000068  0.000068  0.000068
# 19   0.000017  0.000017  0.000017  0.000017  0.000017  0.000017  0.000017
# 20   0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 21   0.000294  0.000294  0.000294  0.000294  0.000294  0.000294  0.000294
# 22   0.000345  0.000345  0.000345  0.000345  0.000345  0.000345  0.424136
# 23   0.000250  0.000250  0.000250  0.000250  0.000250  0.000250  0.000250
# 24   0.000588  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588
# 25   0.000032  0.000032  0.000032  0.000032  0.000032  0.000032  0.000032
# 26   0.000064  0.080094  0.000064  0.000064  0.000064  0.000064  0.000064
# 27   0.000018  0.000018  0.000018  0.000018  0.000018  0.000018  0.000018
# 28   0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 29   0.000250  0.000250  0.000250  0.000250  0.000250  0.000250  0.000250
# ..        ...       ...       ...       ...       ...       ...       ...
# 494  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048
# 495  0.000070  0.000070  0.000070  0.000070  0.000070  0.000070  0.000070
# 496  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059
# 497  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059
# 498  0.000090  0.000090  0.000090  0.000090  0.000090  0.000090  0.000090
# 499  0.000034  0.000034  0.000034  0.264383  0.000034  0.000034  0.000034
# 500  0.000054  0.000054  0.000054  0.000054  0.000054  0.000054  0.034913
# 501  0.000082  0.000082  0.000082  0.000082  0.000082  0.000082  0.610289
# 502  0.000051  0.000051  0.000051  0.000051  0.025963  0.000051  0.000051
# 503  0.000476  0.000476  0.000476  0.000476  0.000476  0.000476  0.000476
# 504  0.000278  0.000278  0.000278  0.000278  0.000278  0.000278  0.000278
# 505  0.000263  0.000263  0.000263  0.000263  0.000263  0.000263  0.000263
# 506  0.000179  0.000179  0.000179  0.000179  0.000179  0.000179  0.768314
# 507  0.000112  0.000112  0.000112  0.000112  0.000112  0.000112  0.000112
# 508  0.000013  0.000013  0.000013  0.000013  0.000013  0.000013  0.000013
# 509  0.000052  0.000052  0.000052  0.000052  0.000052  0.000052  0.000052
# 510  0.000020  0.000020  0.000020  0.240155  0.000020  0.000020  0.000020
# 511  0.000526  0.000526  0.000526  0.000526  0.000526  0.000526  0.000526
# 512  0.000089  0.000089  0.000089  0.000089  0.000089  0.000089  0.000089
# 513  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588
# 514  0.000093  0.000093  0.000093  0.000093  0.000093  0.000093  0.000093
# 515  0.000625  0.000625  0.000625  0.000625  0.000625  0.000625  0.000625
# 516  0.000345  0.000345  0.000345  0.000345  0.000345  0.000345  0.000345
# 517  0.000278  0.000278  0.000278  0.000278  0.000278  0.000278  0.000278
# 518  0.000161  0.000161  0.000161  0.000161  0.000161  0.000161  0.000161
# 519  0.000769  0.000769  0.000769  0.000769  0.000769  0.000769  0.000769
# 520  0.000056  0.000056  0.000056  0.000056  0.000056  0.000056  0.000056
# 521  0.000026  0.000026  0.000026  0.005190  0.000026  0.000026  0.000026
# 522  0.000061  0.000061  0.000061  0.000061  0.000061  0.000061  0.000061
# 523  0.000044  0.000044  0.000044  0.000044  0.000044  0.000044  0.000044
#
#            7         8         9     ...           90        91        92  \
# 0    0.000119  0.000119  0.000119    ...     0.000119  0.000119  0.000119
# 1    0.000588  0.000588  0.000588    ...     0.000588  0.000588  0.000588
# 2    0.000714  0.000714  0.000714    ...     0.000714  0.000714  0.000714
# 3    0.000003  0.000003  0.007449    ...     0.000003  0.000003  0.000003
# 4    0.000189  0.000189  0.000189    ...     0.000189  0.000189  0.000189
# 5    0.000078  0.000078  0.000078    ...     0.000078  0.000078  0.000078
# 6    0.000049  0.000049  0.000049    ...     0.000049  0.000049  0.000049
# 7    0.000031  0.000031  0.000031    ...     0.000031  0.000031  0.000031
# 8    0.000089  0.000089  0.000089    ...     0.000089  0.000089  0.000089
# 9    0.000081  0.000081  0.000081    ...     0.000081  0.000081  0.000081
# 10   0.000031  0.000031  0.000031    ...     0.000031  0.000031  0.000031
# 11   0.000312  0.000312  0.000312    ...     0.000312  0.000312  0.000312
# 12   0.000067  0.000067  0.000067    ...     0.000067  0.000067  0.000067
# 13   0.000087  0.000087  0.000087    ...     0.200995  0.000087  0.000087
# 14   0.000039  0.000039  0.000039    ...     0.000039  0.000039  0.000039
# 15   0.000323  0.000323  0.000323    ...     0.000323  0.000323  0.000323
# 16   0.000130  0.053900  0.000130    ...     0.000130  0.000130  0.000130
# 17   0.000031  0.000031  0.000031    ...     0.000031  0.000031  0.000031
# 18   0.000068  0.000068  0.000068    ...     0.000068  0.000068  0.000068
# 19   0.000017  0.000017  0.147794    ...     0.000017  0.000017  0.000017
# 20   0.000031  0.000031  0.000031    ...     0.000031  0.000031  0.000031
# 21   0.000294  0.000294  0.000294    ...     0.000294  0.000294  0.000294
# 22   0.000345  0.000345  0.000345    ...     0.000345  0.000345  0.000345
# 23   0.000250  0.000250  0.000250    ...     0.000250  0.000250  0.000250
# 24   0.000588  0.000588  0.000588    ...     0.000588  0.000588  0.000588
# 25   0.000032  0.000032  0.000032    ...     0.000032  0.000032  0.000032
# 26   0.000064  0.017588  0.000064    ...     0.000064  0.000064  0.000064
# 27   0.000018  0.000018  0.000018    ...     0.000018  0.000018  0.000018
# 28   0.000040  0.000040  0.000040    ...     0.000040  0.000040  0.000040
# 29   0.000250  0.000250  0.000250    ...     0.000250  0.000250  0.000250
# ..        ...       ...       ...    ...          ...       ...       ...
# 494  0.000048  0.000048  0.000048    ...     0.000048  0.000048  0.000048
# 495  0.000070  0.000070  0.000070    ...     0.000070  0.000070  0.000070
# 496  0.000059  0.000059  0.000059    ...     0.000059  0.000059  0.000059
# 497  0.000059  0.000059  0.000059    ...     0.000059  0.000059  0.000059
# 498  0.000090  0.000090  0.000090    ...     0.000090  0.000090  0.000090
# 499  0.000034  0.000034  0.000034    ...     0.000034  0.000034  0.000034
# 500  0.000054  0.000054  0.000054    ...     0.000054  0.000054  0.000054
# 501  0.000082  0.000082  0.000082    ...     0.000082  0.000082  0.000082
# 502  0.000051  0.000051  0.121678    ...     0.000051  0.000051  0.000051
# 503  0.000476  0.000476  0.000476    ...     0.000476  0.000476  0.000476
# 504  0.000278  0.000278  0.000278    ...     0.000278  0.000278  0.000278
# 505  0.000263  0.000263  0.182418    ...     0.000263  0.000263  0.000263
# 506  0.000179  0.000179  0.000179    ...     0.000179  0.000179  0.000179
# 507  0.000112  0.000112  0.000112    ...     0.000112  0.000112  0.000112
# 508  0.000013  0.000013  0.050791    ...     0.000013  0.000013  0.000013
# 509  0.000052  0.000052  0.000052    ...     0.000052  0.000052  0.000052
# 510  0.000020  0.000020  0.000020    ...     0.120551  0.000020  0.000020
# 511  0.000526  0.000526  0.000526    ...     0.000526  0.000526  0.000526
# 512  0.000089  0.000089  0.000089    ...     0.000089  0.000089  0.000089
# 513  0.000588  0.000588  0.000588    ...     0.000588  0.000588  0.000588
# 514  0.000093  0.000093  0.000093    ...     0.000093  0.000093  0.000093
# 515  0.000625  0.068444  0.000625    ...     0.000625  0.000625  0.000625
# 516  0.000345  0.000345  0.000345    ...     0.000345  0.000345  0.000345
# 517  0.000278  0.000278  0.000278    ...     0.000278  0.000278  0.000278
# 518  0.000161  0.000161  0.000161    ...     0.000161  0.000161  0.000161
# 519  0.000769  0.000769  0.000769    ...     0.000769  0.000769  0.000769
# 520  0.000056  0.000056  0.000056    ...     0.000056  0.000056  0.096932
# 521  0.000026  0.000026  0.000026    ...     0.000026  0.000026  0.231679
# 522  0.000061  0.000061  0.000061    ...     0.000061  0.000061  0.000061
# 523  0.000044  0.000044  0.000044    ...     0.000044  0.000044  0.000044
#
#            93        94        95        96        97        98        99
# 0    0.000119  0.000119  0.000119  0.000119  0.000119  0.000119  0.000119
# 1    0.000588  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588
# 2    0.000714  0.000714  0.000714  0.000714  0.000714  0.000714  0.000714
# 3    0.000003  0.000003  0.002719  0.000415  0.000003  0.033427  0.000003
# 4    0.000189  0.000189  0.108715  0.000189  0.000189  0.000189  0.000189
# 5    0.000078  0.000078  0.000078  0.000078  0.000078  0.000078  0.000078
# 6    0.000049  0.000049  0.000049  0.000049  0.000049  0.000049  0.000049
# 7    0.000031  0.000031  0.000031  0.000031  0.028170  0.000031  0.000031
# 8    0.000089  0.000089  0.000089  0.000089  0.000089  0.000089  0.000089
# 9    0.000081  0.000081  0.000081  0.000081  0.000081  0.000081  0.000081
# 10   0.005376  0.025648  0.000031  0.000031  0.000031  0.000031  0.000031
# 11   0.000312  0.000312  0.000312  0.000312  0.000312  0.000312  0.000312
# 12   0.000067  0.000067  0.000067  0.000067  0.000067  0.000067  0.000067
# 13   0.000087  0.000087  0.000087  0.000087  0.000087  0.000087  0.000087
# 14   0.000039  0.000039  0.000039  0.000039  0.000039  0.000039  0.000039
# 15   0.000323  0.000323  0.000323  0.000323  0.000323  0.000323  0.000323
# 16   0.000130  0.071913  0.000130  0.000130  0.000130  0.000130  0.000130
# 17   0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 18   0.000068  0.000068  0.000068  0.000068  0.000068  0.000068  0.000068
# 19   0.000017  0.000017  0.000017  0.000017  0.000017  0.000017  0.000017
# 20   0.000031  0.000031  0.000031  0.000031  0.000031  0.000031  0.000031
# 21   0.000294  0.000294  0.000294  0.000294  0.000294  0.000294  0.000294
# 22   0.000345  0.000345  0.000345  0.000345  0.000345  0.000345  0.000345
# 23   0.000250  0.000250  0.000250  0.000250  0.000250  0.000250  0.000250
# 24   0.000588  0.000588  0.000588  0.000588  0.000588  0.000588  0.000588
# 25   0.000032  0.000032  0.000032  0.000032  0.000032  0.000032  0.000032
# 26   0.000064  0.000064  0.000064  0.000064  0.000064  0.000064  0.000064
# 27   0.012195  0.000018  0.000018  0.000018  0.000018  0.000018  0.000018
# 28   0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 29   0.000250  0.000250  0.000250  0.000250  0.000250  0.000250  0.000250
# ..        ...       ...       ...       ...       ...       ...       ...
# 494  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048
# 495  0.000070  0.000070  0.000070  0.000070  0.000070  0.048228  0.000070
# 496  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059  0.000059
# 497  0.000059  0.000059  0.000059  0.000059  0.084954  0.000059  0.000059
# 498  0.000090  0.000090  0.000090  0.000090  0.000090  0.000090  0.000090
# 499  0.000034  0.000034  0.000034  0.000034  0.053183  0.000034  0.000034
# 500  0.000054  0.000054  0.000054  0.000054  0.073029  0.093634  0.000054
# 501  0.000082  0.000082  0.000082  0.000082  0.234748  0.000082  0.000082
# 502  0.000051  0.000051  0.000051  0.000051  0.168856  0.000051  0.000051
# 503  0.000476  0.000476  0.000476  0.000476  0.952857  0.000476  0.000476
# 504  0.000278  0.000278  0.000278  0.000278  0.341070  0.000278  0.000278
# 505  0.000263  0.000263  0.000263  0.000263  0.283837  0.000263  0.000263
# 506  0.000179  0.000179  0.000179  0.000179  0.214186  0.000179  0.000179
# 507  0.000112  0.000112  0.000112  0.000112  0.427685  0.000112  0.000112
# 508  0.006649  0.000013  0.000013  0.000013  0.035813  0.034171  0.000013
# 509  0.000052  0.000052  0.000052  0.000052  0.152150  0.000052  0.000052
# 510  0.000020  0.000020  0.000020  0.000020  0.041094  0.003223  0.000020
# 511  0.000526  0.000526  0.000526  0.000526  0.368238  0.000526  0.000526
# 512  0.000089  0.000089  0.000089  0.000089  0.101709  0.000089  0.000089
# 513  0.000588  0.000588  0.000588  0.000588  0.665502  0.000588  0.000588
# 514  0.000093  0.000093  0.000093  0.000093  0.159538  0.000093  0.000093
# 515  0.000625  0.000625  0.000625  0.000625  0.260152  0.000625  0.000625
# 516  0.000345  0.000345  0.000345  0.000345  0.378536  0.000345  0.000345
# 517  0.000278  0.000278  0.000278  0.000278  0.370324  0.000278  0.000278
# 518  0.000161  0.000161  0.000161  0.000161  0.258738  0.000161  0.000161
# 519  0.000769  0.000769  0.000769  0.000769  0.000769  0.000769  0.000769
# 520  0.000056  0.000056  0.000056  0.000056  0.000056  0.000056  0.000056
# 521  0.000026  0.000026  0.000026  0.000026  0.000026  0.000026  0.000026
# 522  0.000061  0.000061  0.000061  0.000061  0.000061  0.000061  0.000061
# 523  0.000044  0.000044  0.000044  0.000044  0.000044  0.000044  0.000044
#
# [524 rows x 100 columns]

# %%
list1= [];
for i in range(0, len(df["Paragraphs"])):
    x = 0;
    for j in range(0, 99):
        if matrix[j][i] > x:
            x = matrix[j][i];
            z = j;
    list1.append(z);

# %%
results = [int(i) for i in list1]

# %%
se = pd.Series(results)

# %%
df['cluster'] = se.values

# %%
df.head()
# Out:
#      Article                                              Title  \
# 1  Article 1                                              Scope
# 2  Article 2                                 Supervisory powers
# 3  Article 3  Application of stricter requirements by instit...
# 4  Article 4                                        Definitions
# 5  Article 5  Definitions specific to capital requirements f...
#
#                                           Paragraphs  \
# 1  This Regulation lays down uniform rules concer...
# 2  For the purposes of ensuring compliance with t...
# 3  This Regulation shall not prevent institutions...
# 4  1.   For the purposes of this Regulation, the ...
# 5  For the purposes of Part Three, Title II, the ...
#
#           References_internal_clean  \
# 1                             [460]
# 2                                []
# 3                                []
# 4  [4, 2, 115, 25, 71, 301, 113, 1]
# 5                                []
#
#                                   Paragraphs_cleaned  cluster
# 1  This Regulation lays down uniform rules concer...       66
# 2  For the purposes of ensuring compliance with t...       40
# 3  This Regulation shall not prevent institutions...       68
# 4  1.   For the purposes of this Regulation, the ...       60
# 5  For the purposes of Part Three, Title II, the ...       58

# %%
cluster = df['cluster'].tolist()
article = df['Article'].tolist()
internal_references = df['References_internal_clean'].tolist()

# %%
crr_articles = { 'article': article,'cluster': cluster, 'internal_references': internal_references}

frame = pd.DataFrame(crr_articles, index = [clusters], columns = ['article', 'cluster', 'internal_references'])

# %%
def assigned_articles(number):
    res = []
    for article in frame.ix[number]['article'].values.tolist():
        res.append(article)
    return res

# %%
frame['assigned_articles'] = frame['cluster'].apply(assigned_articles)
# Out:
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
frame.head()
# Out:
#       article  cluster               internal_references  \
# 66  Article 1       66                             [460]
# 40  Article 2       40                                []
# 68  Article 3       68                                []
# 60  Article 4       60  [4, 2, 115, 25, 71, 301, 113, 1]
# 58  Article 5       58                                []
#
#                                     assigned_articles
# 66  [Article 1, Article 291, Article 307, Article ...
# 40  [Article 2, Article 7, Article 8, Article 9, A...
# 68  [Article 3, Article 280, Article 446, Article ...
# 60  [Article 4, Article 135, Article 267, Article ...
# 58                           [Article 5, Article 272]

# %%
def clean_references(text2):
    res2 = re.findall('\d+(?!\))', text2)
    return res2

# %%
frame['assigned_articles'] = frame['assigned_articles'].astype(str)
frame['assigned_articles'] = frame['assigned_articles'].apply(clean_references)

# %%
frame.head()
# Out:
#       article  cluster               internal_references  \
# 66  Article 1       66                             [460]
# 40  Article 2       40                                []
# 68  Article 3       68                                []
# 60  Article 4       60  [4, 2, 115, 25, 71, 301, 113, 1]
# 58  Article 5       58                                []
#
#                                     assigned_articles
# 66   [1, 291, 307, 308, 309, 310, 311, 424, 427, 428]
# 40  [2, 7, 8, 9, 10, 20, 21, 314, 396, 414, 415, 516]
# 68                                 [3, 280, 446, 454]
# 60                                 [4, 135, 267, 332]
# 58                                           [5, 272]

# %%
def count_references(references):
    references_count = 0
    for i in range(1, len(frame)):
        i = str(i)
        if i in references:
            references_count +=1
    return references_count

# %%
frame['references_count'] = frame['internal_references'].apply(count_references).astype(int)

# %%
frame['assigned_articles_count'] = frame['assigned_articles'].apply(count_references).astype(int)

# %%
frame['correctly_labeled'] = [len(set(a).intersection(b)) for a, b in zip(frame['internal_references'], frame['assigned_articles'])]

# %%
frame['precision'] = (frame['correctly_labeled']/ frame['assigned_articles_count'])

# %%
frame['recall'] = (frame['correctly_labeled']/ frame['references_count'])

# %%
frame.head()
# Out:
#       article  cluster               internal_references  \
# 66  Article 1       66                             [460]
# 40  Article 2       40                                []
# 68  Article 3       68                                []
# 60  Article 4       60  [4, 2, 115, 25, 71, 301, 113, 1]
# 58  Article 5       58                                []
#
#                                     assigned_articles  references_count  \
# 66   [1, 291, 307, 308, 309, 310, 311, 424, 427, 428]                 1
# 40  [2, 7, 8, 9, 10, 20, 21, 314, 396, 414, 415, 516]                 0
# 68                                 [3, 280, 446, 454]                 0
# 60                                 [4, 135, 267, 332]                 8
# 58                                           [5, 272]                 0
#
#     assigned_articles_count  correctly_labeled  precision  recall
# 66                       10                  0       0.00   0.000
# 40                       12                  0       0.00     NaN
# 68                        4                  0       0.00     NaN
# 60                        4                  1       0.25   0.125
# 58                        2                  0       0.00     NaN

# %%
avg_precision = frame['precision'].mean()
avg_recall = frame['recall'].mean()

print('Average Precision 100 cluster: ')
print(avg_precision)
print('Average Recall 100 clusters: ')
print(avg_recall)
# Out:
# Average Precision 100 cluster:
# 0.03488875635493165
# Average Recall 100 clusters:
# 0.15931488249327447
