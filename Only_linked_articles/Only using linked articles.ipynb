# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
result = pd.read_pickle("entireDF_3xtfidf_3xlda_countvec_commonwords.pkl")

# %%
result
# Out:
#           articles1                                        paragraphs1  \
# 0         Article 1  This Regulation lays down uniform rules concer...
# 1         Article 4  1.   For the purposes of this Regulation, the ...
# 2         Article 4  1.   For the purposes of this Regulation, the ...
# 3         Article 4  1.   For the purposes of this Regulation, the ...
# 4         Article 4  1.   For the purposes of this Regulation, the ...
# 5         Article 4  1.   For the purposes of this Regulation, the ...
# 6         Article 4  1.   For the purposes of this Regulation, the ...
# 7         Article 4  1.   For the purposes of this Regulation, the ...
# 8         Article 4  1.   For the purposes of this Regulation, the ...
# 9         Article 6  1.   Institutions shall comply with the obliga...
# 10        Article 6  1.   Institutions shall comply with the obliga...
# 11        Article 6  1.   Institutions shall comply with the obliga...
# ...

# %%
result.head()
# Out:
#    articles1                                        paragraphs1    articles2  \
# 0  Article 1  This Regulation lays down uniform rules concer...  Article 460
# 1  Article 4  1.   For the purposes of this Regulation, the ...    Article 1
# 2  Article 4  1.   For the purposes of this Regulation, the ...    Article 2
# 3  Article 4  1.   For the purposes of this Regulation, the ...    Article 4
# 4  Article 4  1.   For the purposes of this Regulation, the ...   Article 25
#
#                                          paragraphs2  label  tfidf_cosine  \
# 0  1.   The Commission shall be empowered to adop...      1      0.159495
# 1  This Regulation lays down uniform rules concer...      1      0.312056
# 2  For the purposes of ensuring compliance with t...      1      0.208647
# 3  1.   For the purposes of this Regulation, the ...      1      1.000000
# 4  The Tier 1 capital of an institution consists ...      1      0.309379
#
# ...

# %%
new = result.ix[~(result['articles1'] == 'Article 1')]

# %%
new = new.ix[~(new['articles1'] == 'Article 3')]
# Out:
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
new = new.ix[~(new['articles1'] == 'Article 5')]
new = new.ix[~(new['articles1'] == 'Article 10')]
new = new.ix[~(new['articles1'] == 'Article 12')]
new = new.ix[~(new['articles1'] == 'Article 19')]
new = new.ix[~(new['articles1'] == 'Article 24')]
new = new.ix[~(new['articles1'] == 'Article 25')]
new = new.ix[~(new['articles1'] == 'Article 37')]
new = new.ix[~(new['articles1'] == 'Article 39')]
new = new.ix[~(new['articles1'] == 'Article 43')]
new = new.ix[~(new['articles1'] == 'Article 64')]
new = new.ix[~(new['articles1'] == 'Article 66')]
new = new.ix[~(new['articles1'] == 'Article 72')]
new = new.ix[~(new['articles1'] == 'Article 74')]
new = new.ix[~(new['articles1'] == 'Article 77')]
new = new.ix[~(new['articles1'] == 'Article 81')]
new = new.ix[~(new['articles1'] == 'Article 82')]
new = new.ix[~(new['articles1'] == 'Article 89')]
new = new.ix[~(new['articles1'] == 'Article 93')]
new = new.ix[~(new['articles1'] == 'Article 103')]
# Out:
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
new = new.ix[~(new['articles1'] == 'Article 112')]
new = new.ix[~(new['articles1'] == 'Article 118')]
new = new.ix[~(new['articles1'] == 'Article 130')]
new = new.ix[~(new['articles1'] == 'Article 136')]
new = new.ix[~(new['articles1'] == 'Article 138')]
new = new.ix[~(new['articles1'] == 'Article 140')]
new = new.ix[~(new['articles1'] == 'Article 141')]
new = new.ix[~(new['articles1'] == 'Article 145')]
new = new.ix[~(new['articles1'] == 'Article 146')]
new = new.ix[~(new['articles1'] == 'Article 156')]
new = new.ix[~(new['articles1'] == 'Article 167')]
new = new.ix[~(new['articles1'] == 'Article 168')]
new = new.ix[~(new['articles1'] == 'Article 169')]
new = new.ix[~(new['articles1'] == 'Article 170')]
new = new.ix[~(new['articles1'] == 'Article 171')]
new = new.ix[~(new['articles1'] == 'Article 174')]
new = new.ix[~(new['articles1'] == 'Article 175')]
new = new.ix[~(new['articles1'] == 'Article 184')]
new = new.ix[~(new['articles1'] == 'Article 185')]
new = new.ix[~(new['articles1'] == 'Article 186')]
new = new.ix[~(new['articles1'] == 'Article 187')]
new = new.ix[~(new['articles1'] == 'Article 188')]
new = new.ix[~(new['articles1'] == 'Article 189')]
new = new.ix[~(new['articles1'] == 'Article 191')]
new = new.ix[~(new['articles1'] == 'Article 192')]
new = new.ix[~(new['articles1'] == 'Article 193')]
new = new.ix[~(new['articles1'] == 'Article 200')]
new = new.ix[~(new['articles1'] == 'Article 203')]
new = new.ix[~(new['articles1'] == 'Article 204')]
new = new.ix[~(new['articles1'] == 'Article 208')]
new = new.ix[~(new['articles1'] == 'Article 209')]
new = new.ix[~(new['articles1'] == 'Article 219')]
new = new.ix[~(new['articles1'] == 'Article 225')]
new = new.ix[~(new['articles1'] == 'Article 234')]
new = new.ix[~(new['articles1'] == 'Article 238')]
new = new.ix[~(new['articles1'] == 'Article 240')]
new = new.ix[~(new['articles1'] == 'Article 253')]
new = new.ix[~(new['articles1'] == 'Article 255')]
new = new.ix[~(new['articles1'] == 'Article 257')]
new = new.ix[~(new['articles1'] == 'Article 267')]
new = new.ix[~(new['articles1'] == 'Article 268')]
new = new.ix[~(new['articles1'] == 'Article 269')]
new = new.ix[~(new['articles1'] == 'Article 270')]


new = new.ix[~(new['articles1'] == 'Article 271')]
new = new.ix[~(new['articles1'] == 'Article 272')]
new = new.ix[~(new['articles1'] == 'Article 275')]
new = new.ix[~(new['articles1'] == 'Article 277')]
new = new.ix[~(new['articles1'] == 'Article 279')]
new = new.ix[~(new['articles1'] == 'Article 287')]
new = new.ix[~(new['articles1'] == 'Article 290')]
new = new.ix[~(new['articles1'] == 'Article 296')]

new = new.ix[~(new['articles1'] == 'Article 310')]
new = new.ix[~(new['articles1'] == 'Article 313')]
new = new.ix[~(new['articles1'] == 'Article 319')]
new = new.ix[~(new['articles1'] == 'Article 323')]

new = new.ix[~(new['articles1'] == 'Article 325')]
new = new.ix[~(new['articles1'] == 'Article 326')]
new = new.ix[~(new['articles1'] == 'Article 330')]
new = new.ix[~(new['articles1'] == 'Article 333')]



new = new.ix[~(new['articles1'] == 'Article 334')]
new = new.ix[~(new['articles1'] == 'Article 335')]
new = new.ix[~(new['articles1'] == 'Article 338')]
new = new.ix[~(new['articles1'] == 'Article 339')]


new = new.ix[~(new['articles1'] == 'Article 342')]
new = new.ix[~(new['articles1'] == 'Article 343')]
new = new.ix[~(new['articles1'] == 'Article 344')]
new = new.ix[~(new['articles1'] == 'Article 345')]

new = new.ix[~(new['articles1'] == 'Article 346')]
new = new.ix[~(new['articles1'] == 'Article 356')]
new = new.ix[~(new['articles1'] == 'Article 359')]
new = new.ix[~(new['articles1'] == 'Article 360')]


new = new.ix[~(new['articles1'] == 'Article 362')]
new = new.ix[~(new['articles1'] == 'Article 368')]
new = new.ix[~(new['articles1'] == 'Article 369')]
new = new.ix[~(new['articles1'] == 'Article 370')]

new = new.ix[~(new['articles1'] == 'Article 374')]
new = new.ix[~(new['articles1'] == 'Article 375')]
new = new.ix[~(new['articles1'] == 'Article 376')]
new = new.ix[~(new['articles1'] == 'Article 378')]

new = new.ix[~(new['articles1'] == 'Article 381')]
new = new.ix[~(new['articles1'] == 'Article 387')]
new = new.ix[~(new['articles1'] == 'Article 389')]
new = new.ix[~(new['articles1'] == 'Article 391')]


new = new.ix[~(new['articles1'] == 'Article 392')]
new = new.ix[~(new['articles1'] == 'Article 393')]
new = new.ix[~(new['articles1'] == 'Article 404')]
new = new.ix[~(new['articles1'] == 'Article 421')]
new = new.ix[~(new['articles1'] == 'Article 434')]
new = new.ix[~(new['articles1'] == 'Article 435')]
new = new.ix[~(new['articles1'] == 'Article 439')]

new = new.ix[~(new['articles1'] == 'Article 442')]
new = new.ix[~(new['articles1'] == 'Article 447')]
new = new.ix[~(new['articles1'] == 'Article 448')]
new = new.ix[~(new['articles1'] == 'Article 463')]
new = new.ix[~(new['articles1'] == 'Article 464')]

new = new.ix[~(new['articles1'] == 'Article 498')]
new = new.ix[~(new['articles1'] == 'Article 501')]
new = new.ix[~(new['articles1'] == 'Article 505')]
new = new.ix[~(new['articles1'] == 'Article 512')]


new = new.ix[~(new['articles1'] == 'Article 513')]
new = new.ix[~(new['articles1'] == 'Article 515')]
new = new.ix[~(new['articles1'] == 'Article 516')]
new = new.ix[~(new['articles1'] == 'Article 517')]
new = new.ix[~(new['articles1'] == 'Article 518')]
new = new.ix[~(new['articles1'] == 'Article 520')]
# Out:
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /Users/sophiekamuf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
new
# Out:
#           articles1                                        paragraphs1  \
# 1         Article 4  1.   For the purposes of this Regulation, the ...
# 2         Article 4  1.   For the purposes of this Regulation, the ...
# 3         Article 4  1.   For the purposes of this Regulation, the ...
# 4         Article 4  1.   For the purposes of this Regulation, the ...
# 5         Article 4  1.   For the purposes of this Regulation, the ...
# 6         Article 4  1.   For the purposes of this Regulation, the ...
# 7         Article 4  1.   For the purposes of this Regulation, the ...
# 8         Article 4  1.   For the purposes of this Regulation, the ...
# 9         Article 6  1.   Institutions shall comply with the obliga...
# 10        Article 6  1.   Institutions shall comply with the obliga...
# 11        Article 6  1.   Institutions shall comply with the obliga...
# 12        Article 6  1.   Institutions shall comply with the obliga...
# ...

# %%
new.to_pickle('only_linked_articles.pkl')

# %%
train_x = pd.read_pickle("train_x_features8_linksonly.pkl")
train_y = pd.read_pickle("train_y_features8_linksonly.pkl")

# %%
train_x['label'] = train_y['label']

# %%
train_majority = train_x[train_x.label==0]
train_minority = train_x[train_x.label==1]

# %%
train_0_sample = train_majority.sample(n=858)

# %%
df_downsampled = pd.concat([train_minority, train_0_sample])

# %%
df_downsampled.to_pickle('df_train_downsampled_features8_onlylinks.pkl')
